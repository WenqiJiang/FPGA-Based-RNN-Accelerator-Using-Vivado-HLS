# %%
import h5py

iname = "./simple_rnn_1_bias.h5"

f = h5py.File(iname, 'r')
dataset = f['simple_rnn_1/bias:0']
print(list(f.keys()))
print(type(f))
print(type(dataset))
print(dataset.shape)
print(dataset.dtype)
# Out:
# ['simple_rnn_1']
# <class 'h5py._hl.files.File'>
# <class 'h5py._hl.dataset.Dataset'>
# (128,)
# float32

# %%
for i in range(128):
    print("%.30f"%(dataset[i]))
#     print(dataset[i])
# Out:
# -0.089784830808639526367187500000
# 0.055499661713838577270507812500
# -0.113605298101902008056640625000
# -0.065029039978981018066406250000
# -0.183114469051361083984375000000
# -0.011532394215464591979980468750
# -0.169790819287300109863281250000
# -0.204647094011306762695312500000
# 0.346167117357254028320312500000
# -0.470503121614456176757812500000
# 0.328516632318496704101562500000
# -0.255597591400146484375000000000
# -0.485179573297500610351562500000
# -0.075189277529716491699218750000
# 0.245947808027267456054687500000
# -0.008082324638962745666503906250
# 0.333979249000549316406250000000
# -0.061070147901773452758789062500
# -0.253357708454132080078125000000
# -0.399682044982910156250000000000
# 0.333782941102981567382812500000
# 0.142710313200950622558593750000
# 0.185629323124885559082031250000
# 0.249729767441749572753906250000
# -0.189760074019432067871093750000
# -0.033478844910860061645507812500
# -0.135819643735885620117187500000
# -0.321088343858718872070312500000
# ...
