# %%
# %load_ext autoreload
# %autoreload 2

# from IPython.core.interactiveshell import InteractiveShell
# from IPython.display import HTML

# InteractiveShell.ast_node_interactivity = 'all'

# from keras import Model
# from keras.models import load_model
# import warnings
# warnings.filterwarnings('ignore', category = RuntimeWarning)
# warnings.filterwarnings('ignore', category = UserWarning)

# BATCH_SIZE = 2048
# RANDOM_STATE = 50

# import numpy as np
# import pandas as pd
# from utils import get_model, find_closest, get_sequences, create_train_valid,  generate_output, guess_human

# %%
# Set up IPython to show all outputs from a cell
import warnings
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = 'all'

warnings.filterwarnings('ignore', category=RuntimeWarning)

RANDOM_STATE = 50
EPOCHS = 150
BATCH_SIZE = 2048
TRAINING_LENGTH = 50
TRAIN_FRACTION = 0.7
VERBOSE = 0
SAVE_MODEL = True
RNN_CELLS = 128

import pandas as pd
import numpy as np

# Read in data
data = pd.read_csv(
    '../data/neural_network_patent_query.csv', parse_dates=['patent_date'])

# Extract abstracts
original_abstracts = list(data['patent_abstract'])

# %%
def make_sequences(texts,
                   training_length=50,
                   lower=True,
                   filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n'):
    """Turn a set of texts into sequences of integers"""

    # Create the tokenizer object and train on texts
    tokenizer = Tokenizer(lower=lower, filters=filters)
    tokenizer.fit_on_texts(texts)

    # Create look-up dictionaries and reverse look-ups
    word_idx = tokenizer.word_index
    idx_word = tokenizer.index_word
    num_words = len(word_idx) + 1
    word_counts = tokenizer.word_counts

    print(f'There are {num_words} unique words.')

    # Convert text to sequences of integers
    sequences = tokenizer.texts_to_sequences(texts)

    # Limit to sequences with more than training length tokens
    seq_lengths = [len(x) for x in sequences]
    over_idx = [
        i for i, l in enumerate(seq_lengths) if l > (training_length + 20)
    ]

    new_texts = []
    new_sequences = []

    # Only keep sequences with more than training length tokens
    for i in over_idx:
        new_texts.append(texts[i])
        new_sequences.append(sequences[i])

    training_seq = []
    labels = []

    # Iterate through the sequences of tokens
    for seq in new_sequences:

        # Create multiple training examples from each sequence
        for i in range(training_length, len(seq)):
            # Extract the features and label
            extract = seq[i - training_length:i + 1]

            # Set the features and label
            training_seq.append(extract[:-1])
            labels.append(extract[-1])

    print(f'There are {len(training_seq)} training sequences.')

    # Return everything needed for setting up the model
    return word_idx, idx_word, num_words, word_counts, new_texts, new_sequences, training_seq, labels

# %%
from keras.preprocessing.text import Tokenizer

example = 'This is a short sentence (1) with one reference to an image. This next sentence, while non-sensical, does not have an image and has two commas.'
tokenizer = Tokenizer(filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts([example])
s = tokenizer.texts_to_sequences([example])[0]
' '.join(tokenizer.index_word[i] for i in s)
# Out:
# Using TensorFlow backend.
# 'this is a short sentence 1 with one reference to an image this next sentence while non sensical does not have an image and has two commas'

# %%
tokenizer = Tokenizer(filters='"#$%&*+/:;<=>?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts([example])
s = tokenizer.texts_to_sequences([example])[0]
' '.join(tokenizer.index_word[i] for i in s)
tokenizer.word_index.keys()
# Out:
# 'this is a short sentence (1) with one reference to an image. this next sentence, while non-sensical, does not have an image and has two commas.'
# dict_keys(['this', 'an', 'is', 'a', 'short', 'sentence', '(1)', 'with', 'one', 'reference', 'to', 'image.', 'next', 'sentence,', 'while', 'non-sensical,', 'does', 'not', 'have', 'image', 'and', 'has', 'two', 'commas.'])

# %%
import re


def format_patent(patent):
    """Add spaces around punctuation and remove references to images/citations."""

    # Add spaces around punctuation
    patent = re.sub(r'(?<=[^\s0-9])(?=[.,;?])', r' ', patent)

    # Remove references to figures
    patent = re.sub(r'\((\d+)\)', r'', patent)

    # Remove double spaces
    patent = re.sub(r'\s\s', ' ', patent)
    return patent


f = format_patent(example)
f
# Out:
# 'This is a short sentence with one reference to an image . This next sentence , while non-sensical , does not have an image and has two commas .'

# %%
formatted = []

# Iterate through all the original abstracts
for a in original_abstracts:
    formatted.append(format_patent(a))

len(formatted)
# Out:
# 3522

# %%
TRAINING_LENGTH = 50

filters = '!"%;[\\]^_`{|}~\t\n'
word_idx, idx_word, num_words, word_counts, abstracts, sequences, features, labels = make_sequences(
    formatted, TRAINING_LENGTH, lower=False, filters=filters)
# Out:
# There are 16192 unique words.
# There are 318563 training sequences.

# %%
sorted(word_counts.items(), key=lambda x: x[1], reverse=True)[:15]
# Out:
# [('the', 30760),
#  ('a', 21442),
#  ('of', 20157),
#  ('.', 16554),
#  (',', 15415),
#  ('and', 12563),
#  ('to', 12012),
#  ('network', 7618),
#  ('neural', 7235),
#  ('is', 7211),
#  ('for', 6779),
#  ('in', 6131),
#  ('The', 5813),
#  ('an', 5286),
#  ('data', 3971)]

# %%
from sklearn.utils import shuffle


def create_train_valid(features,
                       labels,
                       num_words,
                       train_fraction=TRAIN_FRACTION):
    """Create training and validation features and labels."""

    # Randomly shuffle features and labels
    features, labels = shuffle(features, labels, random_state=RANDOM_STATE)

    # Decide on number of samples for training
    train_end = int(train_fraction * len(labels))

    train_features = np.array(features[:train_end])
    valid_features = np.array(features[train_end:])

    train_labels = labels[:train_end]
    valid_labels = labels[train_end:]

    # Convert to arrays
    X_train, X_valid = np.array(train_features), np.array(valid_features)

    # Using int8 for memory savings
    y_train = np.zeros((len(train_labels), num_words), dtype=np.int8)
    y_valid = np.zeros((len(valid_labels), num_words), dtype=np.int8)

    # One hot encoding of labels
    for example_index, word_index in enumerate(train_labels):
        y_train[example_index, word_index] = 1

    for example_index, word_index in enumerate(valid_labels):
        y_valid[example_index, word_index] = 1

    # Memory management
    import gc
    gc.enable()
    del features, labels, train_features, valid_features, train_labels, valid_labels
    gc.collect()

    return X_train, X_valid, y_train, y_valid

# %%
import os
from keras.utils import get_file

# Vectors to use
glove_vectors = '/home/jwq/.keras/datasets/glove.6B.zip'

# Download word embeddings if they are not present
if not os.path.exists(glove_vectors):
    glove_vectors = get_file('glove.6B.zip',
                             'http://nlp.stanford.edu/data/glove.6B.zip')
    os.system(f'unzip {glove_vectors}')

# Load in unzipped file
glove_vectors = '/home/jwq/.keras/datasets/glove.6B.100d.txt'
glove = np.loadtxt(glove_vectors, dtype='str', comments=None)
glove.shape
glove[0]
# Out:
# (400000, 101)
# array(['the', '-0.038194', '-0.24487', '0.72812', '-0.39961', '0.083172',
#        '0.043953', '-0.39141', '0.3344', '-0.57545', '0.087459',
#        '0.28787', '-0.06731', '0.30906', '-0.26384', '-0.13231',
#        '-0.20757', '0.33395', '-0.33848', '-0.31743', '-0.48336',
#        '0.1464', '-0.37304', '0.34577', '0.052041', '0.44946', '-0.46971',
#        '0.02628', '-0.54155', '-0.15518', '-0.14107', '-0.039722',
#        '0.28277', '0.14393', '0.23464', '-0.31021', '0.086173', '0.20397',
#        '0.52624', '0.17164', '-0.082378', '-0.71787', '-0.41531',
#        '0.20335', '-0.12763', '0.41367', '0.55187', '0.57908', '-0.33477',
#        '-0.36559', '-0.54857', '-0.062892', '0.26584', '0.30205',
#        '0.99775', '-0.80481', '-3.0243', '0.01254', '-0.36942', '2.2167',
#        '0.72201', '-0.24978', '0.92136', '0.034514', '0.46745', '1.1079',
#        '-0.19358', '-0.074575', '0.23353', '-0.052062', '-0.22044',
#        '0.057162', '-0.15806', '-0.30798', '-0.41625', '0.37972',
#        '0.15006', '-0.53212', '-0.2055', '-1.2526', '0.071624', '0.70565',
#        '0.49744', '-0.42063', '0.26148', '-1.538', '-0.30223',
#        '-0.073438', '-0.28312', '0.37104', '-0.25217', '0.016215',
#        '-0.017099', '-0.38984', '0.87424', '-0.72569', '-0.51058',
#        '-0.52028', '-0.1459', '0.8278', '0.27062'], dtype='<U22')

# %%
vectors = glove[:, 1:].astype('float')
words = glove[:, 0]

del glove

vectors[100], words[100]
# Out:
# (array([-3.9551e-01,  5.4660e-01,  5.0315e-01, -6.3682e-01, -4.5470e-01,
#          3.0889e-01, -4.9240e-02,  2.7191e-01,  3.1562e-01, -3.2879e-01,
#          2.5089e-01,  1.4508e-01,  3.5136e-01, -2.2793e-01, -1.5894e-01,
#         -5.1527e-01, -2.7978e-01,  3.6470e-01, -3.9425e-01,  3.3299e-01,
#          4.3051e-01,  1.8300e-01,  2.5095e-01, -1.8547e-01,  3.4698e-01,
#          5.5137e-02, -4.5979e-01, -8.2963e-01, -1.8523e-02, -3.6772e-01,
#          4.5566e-02,  7.1052e-01, -2.2782e-02, -8.0889e-02,  2.0685e-01,
#          4.9855e-01, -5.9794e-02, -8.0048e-03, -2.3823e-01, -3.3759e-01,
#         -2.4201e-01, -2.3788e-01, -1.1362e-03, -4.0395e-01, -4.4859e-01,
#         -3.2189e-01,  4.8405e-01, -2.7999e-02,  1.0148e-01, -9.3585e-01,
#         -8.7522e-02, -3.9959e-01,  3.6545e-01,  1.3726e+00, -3.0713e-01,
#         -2.5940e+00,  2.2431e-01, -4.1168e-02,  1.7765e+00,  4.0010e-01,
#         -1.0996e-01,  1.4178e+00, -2.6154e-01,  1.8617e-01,  7.9328e-01,
#         -1.1709e-01,  8.7541e-01,  4.3911e-01,  3.4711e-01, -2.8515e-01,
#          7.6269e-02, -6.3038e-01,  1.6408e-01, -3.7053e-01,  5.8485e-01,
#         -1.5472e-01, -2.6382e-01, -1.8590e-01, -7.5228e-01, -1.5752e-01,
#          7.8539e-01, -1.8846e-02, -8.0130e-01,  1.5561e-01, -1.8624e+00,
#         -1.6969e-01,  1.9419e-01, -3.0683e-01, -7.8067e-01, -4.9689e-01,
#         -1.8256e-01, -4.2016e-02, -2.6290e-01,  5.8531e-02, -4.4664e-01,
#         -9.9765e-02, -4.3050e-01, -2.3693e-01, -1.4519e-02,  3.1981e-01]),
#  'so')

# %%
word_idx
# Out:
# {'the': 1,
#  'a': 2,
#  'of': 3,
#  '.': 4,
#  ',': 5,
#  'and': 6,
#  'to': 7,
#  'network': 8,
#  'neural': 9,
#  'is': 10,
#  'for': 11,
#  'in': 12,
#  'The': 13,
#  'an': 14,
#  'data': 15,
#  'are': 16,
#  'by': 17,
#  'A': 18,
#  'input': 19,
#  'system': 20,
#  'with': 21,
#  'output': 22,
#  'or': 23,
#  'from': 24,
#  'which': 25,
#  'be': 26,
#  'as': 27,
#  'that': 28,
#  'on': 29,
#  'signal': 30,
#  'method': 31,
#  'each': 32,
#  'one': 33,
#  'image': 34,
#  'at': 35,
#  'using': 36,
#  'plurality': 37,
#  'first': 38,
#  'layer': 39,
#  'can': 40,
#  'includes': 41,
#  'set': 42,
#  'training': 43,
#  'control': 44,
#  'may': 45,
#  'processing': 46,
#  'based': 47,
#  'values': 48,
#  'second': 49,
#  'information': 50,
#  'signals': 51,
#  'model': 52,
#  'value': 53,
#  'used': 54,
#  'process': 55,
#  'learning': 56,
#  'neuron': 57,
#  'least': 58,
#  'pattern': 59,
#  'such': 60,
#  'device': 61,
#  'between': 62,
#  'time': 63,
#  'In': 64,
#  'circuit': 65,
#  'vector': 66,
#  'unit': 67,
#  'having': 68,
#  'into': 69,
#  'neurons': 70,
#  'apparatus': 71,
#  'function': 72,
#  'trained': 73,
#  'more': 74,
#  'invention': 75,
#  'An': 76,
#  'parameters': 77,
#  'provided': 78,
#  'corresponding': 79,
#  'feature': 80,
#  'recognition': 81,
#  'artificial': 82,
#  'networks': 83,
#  'has': 84,
#  'also': 85,
#  'weight': 86,
#  'number': 87,
#  'then': 88,
#  'state': 89,
#  'inputs': 90,
#  'present': 91,
#  'object': 92,
#  'memory': 93,
#  'speech': 94,
#  'including': 95,
#  'associated': 96,
#  'computer': 97,
#  'comprises': 98,
#  'other': 99,
#  'through': 100,
#  'images': 101,
#  'sensor': 102,
#  'outputs': 103,
#  'within': 104,
#  'parameter': 105,
#  'vectors': 106,
#  'error': 107,
#  'use': 108,
#  'generate': 109,
#  'operation': 110,
#  'determined': 111,
#  'nodes': 112,
#  'current': 113,
#  'controller': 114,
#  'Each': 115,
#  'elements': 116,
#  'user': 117,
#  'node': 118,
#  'connected': 119,
#  'predetermined': 120,
#  'weights': 121,
#  'response': 122,
#  'processor': 123,
#  'systems': 124,
#  'provides': 125,
#  'features': 126,
#  'determine': 127,
#  'determining': 128,
#  'analysis': 129,
#  'patterns': 130,
#  'digital': 131,
#  'target': 132,
#  'disclosed': 133,
#  'selected': 134,
#  'different': 135,
#  'stored': 136,
#  'means': 137,
#  'algorithm': 138,
#  'being': 139,
#  'generated': 140,
#  'provide': 141,
#  'include': 142,
#  'generating': 143,
#  'array': 144,
#  'and/or': 145,
#  'multiple': 146,
#  'module': 147,
#  'structure': 148,
#  'This': 149,
#  'methods': 150,
#  'so': 151,
#  'respective': 152,
#  'applied': 153,
#  'when': 154,
#  'obtained': 155,
#  'classification': 156,
#  'two': 157,
#  'said': 158,
#  '.sub': 159,
#  'element': 160,
#  'during': 161,
#  'wherein': 162,
#  'variables': 163,
#  'further': 164,
#  'form': 165,
#  'embodiment': 166,
#  'vehicle': 167,
#  'comprising': 168,
#  'desired': 169,
#  'color': 170,
#  'matrix': 171,
#  'sequence': 172,
#  'this': 173,
#  'detection': 174,
#  'according': 175,
#  'synapse': 176,
#  'fuzzy': 177,
#  'result': 178,
#  'receiving': 179,
#  'providing': 180,
#  'it': 181,
#  'not': 182,
#  'results': 183,
#  'representing': 184,
#  'hidden': 185,
#  'sets': 186,
#  'connection': 187,
#  'all': 188,
#  'characteristics': 189,
#  'layers': 190,
#  'its': 191,
#  'uses': 192,
#  'predicted': 193,
#  'operating': 194,
#  'component': 195,
#  'configured': 196,
#  'units': 197,
#  'example': 198,
#  'frequency': 199,
#  'processed': 200,
#  'engine': 201,
#  'new': 202,
#  'generates': 203,
#  'light': 204,
#  'adaptive': 205,
#  'characteristic': 206,
#  'particular': 207,
#  'performance': 208,
#  'receives': 209,
#  'than': 210,
#  'position': 211,
#  'condition': 212,
#  'functions': 213,
#  'have': 214,
#  'produce': 215,
#  'order': 216,
#  'conditions': 217,
#  'detected': 218,
#  'performed': 219,
#  'part': 220,
#  'optical': 221,
#  'type': 222,
#  'models': 223,
#  'reference': 224,
#  'level': 225,
#  'logic': 226,
#  'components': 227,
#  'known': 228,
#  'received': 229,
#  'variable': 230,
#  'measured': 231,
#  'sample': 232,
#  'voltage': 233,
#  'given': 234,
#  'performing': 235,
#  'any': 236,
#  'analog': 237,
#  'difference': 238,
#  'threshold': 239,
#  'upon': 240,
#  'high': 241,
#  'detecting': 242,
#  'extracted': 243,
#  'group': 244,
#  'another': 245,
#  'storage': 246,
#  'whether': 247,
#  'described': 248,
#  'section': 249,
#  'objects': 250,
#  'where': 251,
#  'rate': 252,
#  'portion': 253,
#  'accordance': 254,
#  'devices': 255,
#  'temperature': 256,
#  'been': 257,
#  'basis': 258,
#  'application': 259,
#  'computing': 260,
#  'controlling': 261,
#  'location': 262,
#  'power': 263,
#  'via': 264,
#  'synaptic': 265,
#  'acoustic': 266,
#  'controlled': 267,
#  'area': 268,
#  'electronic': 269,
#  'feedback': 270,
#  'character': 271,
#  'space': 272,
#  'nonlinear': 273,
#  'out': 274,
#  'circuits': 275,
#  'techniques': 276,
#  'samples': 277,
#  'classifier': 278,
#  'cell': 279,
#  'sensors': 280,
#  'representation': 281,
#  'same': 282,
#  'these': 283,
#  'coupled': 284,
#  'energy': 285,
#  'point': 286,
#  'single': 287,
#  'database': 288,
#  'various': 289,
#  'both': 290,
#  'points': 291,
#  'region': 292,
#  'calculated': 293,
#  'field': 294,
#  'steps': 295,
#  'representative': 296,
#  'combination': 297,
#  'linear': 298,
#  'audio': 299,
#  'thereby': 300,
#  'architecture': 301,
#  'train': 302,
#  'program': 303,
#  'over': 304,
#  'weighted': 305,
#  'cells': 306,
#  'weighting': 307,
#  'formed': 308,
#  'prediction': 309,
#  'source': 310,
#  'block': 311,
#  'change': 312,
#  'event': 313,
#  'video': 314,
#  'class': 315,
#  'if': 316,
#  '.g': 317,
#  'convolutional': 318,
#  'implemented': 319,
#  'only': 320,
#  'noise': 321,
#  'internal': 322,
#  'intermediate': 323,
#  'coefficients': 324,
#  'test': 325,
#  'product': 326,
#  'dynamic': 327,
#  'obtain': 328,
#  'decision': 329,
#  'indicative': 330,
#  'patient': 331,
#  'content': 332,
#  'machine': 333,
#  'monitoring': 334,
#  'well': 335,
#  'storing': 336,
#  'distance': 337,
#  'determines': 338,
#  'actual': 339,
#  'integrated': 340,
#  'local': 341,
#  'parallel': 342,
#  'measurements': 343,
#  'series': 344,
#  'made': 345,
#  'connections': 346,
#  'automatically': 347,
#  'derived': 348,
#  'physical': 349,
#  'step': 350,
#  'initial': 351,
#  'plant': 352,
#  'phase': 353,
#  'extraction': 354,
#  'filter': 355,
#  'combined': 356,
#  'mode': 357,
#  'specific': 358,
#  'pressure': 359,
#  'identify': 360,
#  'subject': 361,
#  'related': 362,
#  'line': 363,
#  'regions': 364,
#  'map': 365,
#  'while': 366,
#  'back': 367,
#  'search': 368,
#  'pixel': 369,
#  'rules': 370,
#  'estimated': 371,
#  'either': 372,
#  'receive': 373,
#  'detector': 374,
#  'about': 375,
#  'third': 376,
#  'processes': 377,
#  'rule': 378,
#  'domain': 379,
#  'range': 380,
#  'identifying': 381,
#  'measurement': 382,
#  'distribution': 383,
#  'learned': 384,
#  'capable': 385,
#  'calculating': 386,
#  'quality': 387,
#  'measuring': 388,
#  'individual': 389,
#  'perform': 390,
#  'flow': 391,
#  'real': 392,
#  'without': 393,
#  'optimal': 394,
#  'correction': 395,
#  'communication': 396,
#  'after': 397,
#  'text': 398,
#  'unknown': 399,
#  'defined': 400,
#  'channel': 401,
#  'speed': 402,
#  'base': 403,
#  'interface': 404,
#  'operations': 405,
#  'words': 406,
#  'binary': 407,
#  'evaluation': 408,
#  'N': 409,
#  'environment': 410,
#  'candidate': 411,
#  'real-time': 412,
#  'their': 413,
#  'surface': 414,
#  'amount': 415,
#  'technique': 416,
#  'synapses': 417,
#  'visual': 418,
#  'probability': 419,
#  'adapted': 420,
#  'recurrent': 421,
#  'identified': 422,
#  'preferably': 423,
#  'electrical': 424,
#  'utilizing': 425,
#  'Neural': 426,
#  'activation': 427,
#  'characters': 428,
#  'presented': 429,
#  'predicting': 430,
#  'predict': 431,
#  'applying': 432,
#  'changes': 433,
#  'factors': 434,
#  'query': 435,
#  'levels': 436,
#  'potential': 437,
#  'motor': 438,
#  'ANN': 439,
#  'transform': 440,
#  'category': 441,
#  'three': 442,
#  'lines': 443,
#  'identification': 444,
#  'One': 445,
#  'estimate': 446,
#  'inference': 447,
#  'pixels': 448,
#  'interconnected': 449,
#  'produced': 450,
#  'degree': 451,
#  'display': 452,
#  'some': 453,
#  'obtaining': 454,
#  'those': 455,
#  'automatic': 456,
#  'deep': 457,
#  'ratio': 458,
#  'document': 459,
#  'among': 460,
#  'calculation': 461,
#  'detect': 462,
#  'arrangement': 463,
#  'knowledge': 464,
#  'For': 465,
#  'code': 466,
#  'These': 467,
#  'along': 468,
#  'accuracy': 469,
#  'adjusted': 470,
#  'language': 471,
#  'pair': 472,
#  'spatial': 473,
#  '(e': 474,
#  'will': 475,
#  'estimation': 476,
#  'compared': 477,
#  'media': 478,
#  'analyzing': 479,
#  'inputted': 480,
#  'transmission': 481,
#  'thereof': 482,
#  'original': 483,
#  'sum': 484,
#  'relationship': 485,
#  'possible': 486,
#  'coupling': 487,
#  'If': 488,
#  'respect': 489,
#  'normal': 490,
#  'recognize': 491,
#  'relative': 492,
#  'interest': 493,
#  'extracting': 494,
#  'problem': 495,
#  'allows': 496,
#  'containing': 497,
#  'optimization': 498,
#  'states': 499,
#  'context': 500,
#  'activity': 501,
#  'employed': 502,
#  'pulse': 503,
#  'relates': 504,
#  'selection': 505,
#  'final': 506,
#  'stage': 507,
#  'selecting': 508,
#  'thus': 509,
#  'size': 510,
#  'mapping': 511,
#  'similar': 512,
#  'utilized': 513,
#  'embodiments': 514,
#  'Methods': 515,
#  'non-linear': 516,
#  'large': 517,
#  'locations': 518,
#  'supplied': 519,
#  'waveform': 520,
#  'modeling': 521,
#  'cost': 522,
#  'indicating': 523,
#  'produces': 524,
#  'behavior': 525,
#  'terms': 526,
#  'manner': 527,
#  'human': 528,
#  'external': 529,
#  'under': 530,
#  'estimating': 531,
#  'frames': 532,
#  'frame': 533,
#  'constructed': 534,
#  'determination': 535,
#  'station': 536,
#  'computed': 537,
#  'outputting': 538,
#  'classes': 539,
#  'gas': 540,
#  'complex': 541,
#  'performs': 542,
#  'bit': 543,
#  'strength': 544,
#  'face': 545,
#  'arranged': 546,
#  'addition': 547,
#  'programs': 548,
#  'traffic': 549,
#  'improved': 550,
#  'modified': 551,
#  'charge': 552,
#  'comparing': 553,
#  'transformed': 554,
#  'represents': 555,
#  'word': 556,
#  'driving': 557,
#  'resulting': 558,
#  'gate': 559,
#  'recognizing': 560,
#  'clusters': 561,
#  'fault': 562,
#  'design': 563,
#  'associative': 564,
#  'body': 565,
#  'classifying': 566,
#  'events': 567,
#  'template': 568,
#  'matching': 569,
#  'utilizes': 570,
#  'spectral': 571,
#  'times': 572,
#  'low': 573,
#  'score': 574,
#  'material': 575,
#  'previously': 576,
#  'appropriate': 577,
#  'represented': 578,
#  'learn': 579,
#  'voice': 580,
#  'but': 581,
#  'attributes': 582,
#  'reduced': 583,
#  'brain': 584,
#  'expert': 585,
#  'normalized': 586,
#  'automated': 587,
#  'monitored': 588,
#  'action': 589,
#  'encoded': 590,
#  'inputting': 591,
#  'optimum': 592,
#  'algorithms': 593,
#  'comparison': 594,
#  'respectively': 595,
#  'forming': 596,
#  'producing': 597,
#  'implementation': 598,
#  'predictive': 599,
#  'window': 600,
#  'processors': 601,
#  'configuration': 602,
#  'propagation': 603,
#  'classified': 604,
#  'additional': 605,
#  'quantity': 606,
#  'required': 607,
#  'software': 608,
#  'preferred': 609,
#  'At': 610,
#  'statistical': 611,
#  'represent': 612,
#  'correlation': 613,
#  'recognized': 614,
#  'subset': 615,
#  'segment': 616,
#  'collected': 617,
#  'spectrum': 618,
#  'most': 619,
#  'responsive': 620,
#  'hardware': 621,
#  'properties': 622,
#  'electrode': 623,
#  'measure': 624,
#  'relating': 625,
#  'global': 626,
#  'differential': 627,
#  'presence': 628,
#  'operates': 629,
#  'shape': 630,
#  'minimum': 631,
#  'located': 632,
#  'path': 633,
#  'optimized': 634,
#  'until': 635,
#  'direction': 636,
#  'sensing': 637,
#  'up': 638,
#  'tissue': 639,
#  'transformation': 640,
#  'applications': 641,
#  'future': 642,
#  'groups': 643,
#  'mechanism': 644,
#  'standard': 645,
#  'When': 646,
#  'assigned': 647,
#  'conventional': 648,
#  'movement': 649,
#  'case': 650,
#  'mobile': 651,
#  'distributed': 652,
#  'types': 653,
#  'select': 654,
#  'fed': 655,
#  'stream': 656,
#  'electric': 657,
#  'corresponds': 658,
#  'analyzed': 659,
#  'fixed': 660,
#  'transfer': 661,
#  'combustion': 662,
#  'available': 663,
#  'together': 664,
#  'phoneme': 665,
#  'common': 666,
#  'whose': 667,
#  'signature': 668,
#  'directly': 669,
#  'air': 670,
#  'coefficient': 671,
#  'cluster': 672,
#  'maximum': 673,
#  'core': 674,
#  'contains': 675,
#  'approach': 676,
#  'index': 677,
#  'several': 678,
#  'load': 679,
#  'included': 680,
#  'pairs': 681,
#  'collection': 682,
#  'Network': 683,
#  'computation': 684,
#  'create': 685,
#  'medium': 686,
#  'access': 687,
#  'match': 688,
#  'herein': 689,
#  'generator': 690,
#  'average': 691,
#  'improve': 692,
#  'prior': 693,
#  'period': 694,
#  'converting': 695,
#  'person': 696,
#  'production': 697,
#  'density': 698,
#  'calculates': 699,
#  'amplifier': 700,
#  'general': 701,
#  'necessary': 702,
#  'semiconductor': 703,
#  'medical': 704,
#  'following': 705,
#  'formation': 706,
#  'background': 707,
#  'analyzer': 708,
#  'subsequent': 709,
#  'classify': 710,
#  'converted': 711,
#  'column': 712,
#  'wavelet': 713,
#  'radiation': 714,
#  'previous': 715,
#  'After': 716,
#  'physiological': 717,
#  'genetic': 718,
#  'stores': 719,
#  'correspond': 720,
#  'likelihood': 721,
#  'evaluating': 722,
#  'estimates': 723,
#  'camera': 724,
#  'angle': 725,
#  'useful': 726,
#  'center': 727,
#  'generation': 728,
#  'controls': 729,
#  'operational': 730,
#  'lower': 731,
#  'spike': 732,
#  'breathing': 733,
#  'diagnostic': 734,
#  'reduce': 735,
#  'electrodes': 736,
#  'During': 737,
#  'created': 738,
#  'cycle': 739,
#  'forward': 740,
#  'effect': 741,
#  'volume': 742,
#  'Fourier': 743,
#  'intelligent': 744,
#  'vibration': 745,
#  'drive': 746,
#  'communications': 747,
#  'efficiency': 748,
#  'measures': 749,
#  'table': 750,
#  'technology': 751,
#  'partial': 752,
#  'transmitted': 753,
#  'achieved': 754,
#  'service': 755,
#  'conversion': 756,
#  'floating': 757,
#  'representations': 758,
#  'suitable': 759,
#  'relationships': 760,
#  'updated': 761,
#  'dimension': 762,
#  'heart': 763,
#  'packet': 764,
#  'monitor': 765,
#  'analyzes': 766,
#  'smaller': 767,
#  'imaging': 768,
#  'categories': 769,
#  'It': 770,
#  'operate': 771,
#  'delay': 772,
#  'characterized': 773,
#  'interconnection': 774,
#  'tool': 775,
#  'moving': 776,
#  'confidence': 777,
#  'main': 778,
#  'total': 779,
#  'positions': 780,
#  'read': 781,
#  'solution': 782,
#  'adjusting': 783,
#  'speaker': 784,
#  'loop': 785,
#  'historical': 786,
#  'setting': 787,
#  'abnormal': 788,
#  'n': 789,
#  'etc': 790,
#  'fluid': 791,
#  'scores': 792,
#  'implementing': 793,
#  'sampling': 794,
#  'membership': 795,
#  'health': 796,
#  'By': 797,
#  'discrete': 798,
#  'store': 799,
#  'key': 800,
#  'row': 801,
#  '(ANN)': 802,
#  'comprise': 803,
#  'cardiac': 804,
#  'structures': 805,
#  'operator': 806,
#  'similarity': 807,
#  'problems': 808,
#  'primary': 809,
#  'higher': 810,
#  'battery': 811,
#  'errors': 812,
#  'modules': 813,
#  'particularly': 814,
#  'temporal': 815,
#  'objective': 816,
#  'variety': 817,
#  'dimensional': 818,
#  'multiplier': 819,
#  'three-dimensional': 820,
#  'aspect': 821,
#  'e': 822,
#  'correct': 823,
#  'indicates': 824,
#  'basic': 825,
#  'calculate': 826,
#  'testing': 827,
#  'efficient': 828,
#  'spiking': 829,
#  'documents': 830,
#  'accurate': 831,
#  'active': 832,
#  'portions': 833,
#  'accurately': 834,
#  'making': 835,
#  'employs': 836,
#  'unsupervised': 837,
#  'semantic': 838,
#  'hybrid': 839,
#  'onto': 840,
#  'supervised': 841,
#  'examples': 842,
#  'certain': 843,
#  'filtering': 844,
#  'factor': 845,
#  'resistance': 846,
#  'products': 847,
#  'independent': 848,
#  'bus': 849,
#  'small': 850,
#  'joint': 851,
#  'converter': 852,
#  'scheme': 853,
#  'sequences': 854,
#  'DNN': 855,
#  'length': 856,
#  'dependent': 857,
#  'water': 858,
#  'neuronal': 859,
#  'thermal': 860,
#  'sound': 861,
#  'highly': 862,
#  'substantially': 863,
#  'Once': 864,
#  'capability': 865,
#  'magnetic': 866,
#  'carried': 867,
#  'plural': 868,
#  'scale': 869,
#  'motion': 870,
#  'computational': 871,
#  'address': 872,
#  'intelligence': 873,
#  'relevant': 874,
#  'tensor': 875,
#  'employing': 876,
#  'simultaneously': 877,
#  'updating': 878,
#  'Systems': 879,
#  'feedforward': 880,
#  'creating': 881,
#  'actions': 882,
#  'utterance': 883,
#  'To': 884,
#  'Thus': 885,
#  'As': 886,
#  'overall': 887,
#  'infrared': 888,
#  'quantities': 889,
#  'beam': 890,
#  'back-propagation': 891,
#  'directed': 892,
#  'digitized': 893,
#  'selects': 894,
#  'Also': 895,
#  'fuel': 896,
#  'before': 897,
#  'gradient': 898,
#  'positive': 899,
#  'concentration': 900,
#  'functional': 901,
#  'probabilities': 902,
#  'adjust': 903,
#  'Then': 904,
#  'displayed': 905,
#  'existing': 906,
#  'switch': 907,
#  'many': 908,
#  'transmitting': 909,
#  'extract': 910,
#  'adjustment': 911,
#  'no': 912,
#  'random': 913,
#  'inverse': 914,
#  'term': 915,
#  'detects': 916,
#  'taken': 917,
#  'net': 918,
#  'depending': 919,
#  'maps': 920,
#  'risk': 921,
#  'status': 922,
#  'molecular': 923,
#  'regression': 924,
#  'history': 925,
#  'chip': 926,
#  'selectively': 927,
#  'cause': 928,
#  'programmed': 929,
#  'changed': 930,
#  'manufacturing': 931,
#  'was': 932,
#  'operable': 933,
#  'seismic': 934,
#  'sources': 935,
#  'transistor': 936,
#  'simple': 937,
#  'sequentially': 938,
#  'depth': 939,
#  'equal': 940,
#  'segmented': 941,
#  'item': 942,
#  'drilling': 943,
#  'axon': 944,
#  'dynamically': 945,
#  'tasks': 946,
#  'evaluated': 947,
#  'segmentation': 948,
#  'resolution': 949,
#  'Embodiments': 950,
#  'wireless': 951,
#  "user's": 952,
#  'property': 953,
#  'circuitry': 954,
#  'programmable': 955,
#  'Additionally': 956,
#  'switching': 957,
#  'thereto': 958,
#  'contained': 959,
#  'way': 960,
#  'blocks': 961,
#  'list': 962,
#  'less': 963,
#  'paths': 964,
#  'novel': 965,
#  'procedure': 966,
#  'differences': 967,
#  'generally': 968,
#  'combining': 969,
#  'does': 970,
#  'run': 971,
#  'changing': 972,
#  'natural': 973,
#  'continuous': 974,
#  'format': 975,
#  'Such': 976,
#  'there': 977,
#  'users': 978,
#  'items': 979,
#  'reduction': 980,
#  'picture': 981,
#  'amplitude': 982,
#  'quantization': 983,
#  'channels': 984,
#  'Further': 985,
#  'developed': 986,
#  'tracking': 987,
#  'filters': 988,
#  'records': 989,
#  'separate': 990,
#  'enable': 991,
#  'significant': 992,
#  'involves': 993,
#  'expected': 994,
#  'mathematical': 995,
#  'enables': 996,
#  'teaching': 997,
#  'intensity': 998,
#  'support': 999,
#  'areas': 1000,
#  ...}

# %%
word_lookup = {word: vector for word, vector in zip(words, vectors)}

embedding_matrix = np.zeros((num_words, vectors.shape[1]))

not_found = 0

for i, word in enumerate(word_idx.keys()):
    # Look up the word embedding
    vector = word_lookup.get(word, None)

    # Record in matrix
    if vector is not None:
        embedding_matrix[i + 1, :] = vector
    else:
        not_found += 1

print(f'There were {not_found} words without pre-trained embeddings.')
# Out:
# There were 6317 words without pre-trained embeddings.

# %%
embedding_matrix = np.zeros((num_words, len(word_lookup['the'])))

not_found = 0

for i, word in enumerate(word_idx.keys()):
    # Look up the word embedding
    vector = word_lookup.get(word, None)

    # Record in matrix
    if vector is not None:
        embedding_matrix[i + 1, :] = vector
    else:
        not_found += 1

print(f'There were {not_found} words without pre-trained embeddings.')
embedding_matrix.shape
# Out:
# There were 6317 words without pre-trained embeddings.
# (16192, 100)

# %%
embedding_matrix[1]
# Out:
# array([-0.038194, -0.24487 ,  0.72812 , -0.39961 ,  0.083172,  0.043953,
#        -0.39141 ,  0.3344  , -0.57545 ,  0.087459,  0.28787 , -0.06731 ,
#         0.30906 , -0.26384 , -0.13231 , -0.20757 ,  0.33395 , -0.33848 ,
#        -0.31743 , -0.48336 ,  0.1464  , -0.37304 ,  0.34577 ,  0.052041,
#         0.44946 , -0.46971 ,  0.02628 , -0.54155 , -0.15518 , -0.14107 ,
#        -0.039722,  0.28277 ,  0.14393 ,  0.23464 , -0.31021 ,  0.086173,
#         0.20397 ,  0.52624 ,  0.17164 , -0.082378, -0.71787 , -0.41531 ,
#         0.20335 , -0.12763 ,  0.41367 ,  0.55187 ,  0.57908 , -0.33477 ,
#        -0.36559 , -0.54857 , -0.062892,  0.26584 ,  0.30205 ,  0.99775 ,
#        -0.80481 , -3.0243  ,  0.01254 , -0.36942 ,  2.2167  ,  0.72201 ,
#        -0.24978 ,  0.92136 ,  0.034514,  0.46745 ,  1.1079  , -0.19358 ,
#        -0.074575,  0.23353 , -0.052062, -0.22044 ,  0.057162, -0.15806 ,
#        -0.30798 , -0.41625 ,  0.37972 ,  0.15006 , -0.53212 , -0.2055  ,
#        -1.2526  ,  0.071624,  0.70565 ,  0.49744 , -0.42063 ,  0.26148 ,
#        -1.538   , -0.30223 , -0.073438, -0.28312 ,  0.37104 , -0.25217 ,
#         0.016215, -0.017099, -0.38984 ,  0.87424 , -0.72569 , -0.51058 ,
#        -0.52028 , -0.1459  ,  0.8278  ,  0.27062 ])

# %%
# Split into training and validation
X_train, X_valid, y_train, y_valid = create_train_valid(
    features, labels, num_words)
X_train.shape, y_train.shape
# Out:
# ((222994, 50), (222994, 16192))

# %%
import sys
sys.getsizeof(y_train) / 1e9

def check_sizes(gb_min=1):
    for x in globals():
        size = sys.getsizeof(eval(x)) / 1e9
        if size > gb_min:
            print(f'Object: {x:10}\tSize: {size} GB.')

check_sizes(gb_min=1)
# Out:
# 3.61071896
# Object: y_train   	Size: 3.61071896 GB.
# Object: y_valid   	Size: 1.54745336 GB.

# %%
# model
from keras.models import Sequential, load_model
from keras.layers import LSTM, Dense, Dropout, Embedding, Masking, Bidirectional, SimpleRNN
from keras.optimizers import Adam

from keras.utils import plot_model

def make_word_level_model(num_words,
                          embedding_matrix,
                          rnn_cells=128,
                          trainable=False,
                          rnn_layers=1,
                          bi_direc=False):
    """Make a word level recurrent neural network with option for pretrained embeddings
       and varying numbers of RNN cell layers."""

    model = Sequential()

    # Map words to an embedding
    if not trainable:
        model.add(
            Embedding(
                input_dim=num_words,
                output_dim=embedding_matrix.shape[1],
                weights=[embedding_matrix],
                trainable=False,
                mask_zero=True))
        model.add(Masking())
    else:
        model.add(
            Embedding(
                input_dim=num_words,
                output_dim=embedding_matrix.shape[1],
                weights=[embedding_matrix],
                trainable=True))

    # If want to add multiple RNN layers
    if rnn_layers > 1:
        for i in range(rnn_layers - 1):
            model.add(
                SimpleRNN(
                    rnn_cells,
                    return_sequences=True,
                    dropout=0.1,
                    recurrent_dropout=0.1))

    # Add final RNN cell layer
    if bi_direc:
        model.add(
            Bidirectional(
                SimpleRNN(
                    rnn_cells,
                    return_sequences=False,
                    dropout=0.1,
                    recurrent_dropout=0.1)))
    else:
        model.add(
            SimpleRNN(
                rnn_cells,
                return_sequences=False,
                dropout=0.1,
                recurrent_dropout=0.1))
#     model.add(Dense(128, activation='relu'))
#     # Dropout for regularization
#     model.add(Dropout(0.5))

    # Output layer
    model.add(Dense(num_words, activation='softmax'))

    # Compile the model
    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy'])
    return model


model = make_word_level_model(
    num_words,
    embedding_matrix=embedding_matrix,
    rnn_cells=RNN_CELLS,
    trainable=False,
    rnn_layers=1)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 100)         1619200
# _________________________________________________________________
# masking_1 (Masking)          (None, None, 100)         0
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 128)               29312
# _________________________________________________________________
# dense_1 (Dense)              (None, 16192)             2088768
# =================================================================
# Total params: 3,737,280
# Trainable params: 2,118,080
# Non-trainable params: 1,619,200
# _________________________________________________________________

# %%
from keras.models import Model

model_name = 'train-embeddings-rnn-50'
model_dir = '../my_models/'
model = load_model(f'{model_dir}{model_name}.h5')

seed = [633, 5033, 21, 1, 4117, 30, 633, 3770, 12, 1, 22, 122, 4, 5478, 1, 44, 3, 25, 5696, 
 30, 5, 1, 4117, 30, 633, 4039, 7, 1, 22, 122, 3, 1, 810, 216, 8321, 10, 3188, 17, 14,
 2829, 741, 5, 366, 1, 4117, 30, 633, 182, 4039, 7]
# seed = [1, 2]
# layer_name = 'simple_rnn_1'
layer_name = 'simple_rnn_1'
intermediate_layer_model = Model(inputs=model.input,
                                 outputs=model.get_layer(layer_name).output)
simple_rnn_output = intermediate_layer_model.predict(np.array(seed).reshape(1, -1))[0].astype(
                np.float32)

print(simple_rnn_output.shape, '\n', simple_rnn_output)
# print(np.argmax(intermediate_output))
# Out:
# (128,)
#  [-0.99484414 -0.9985863   0.96538794 -0.9971069  -0.9999969   0.9998633
#  -0.9549347   0.99972117  0.8981451  -0.99784255 -0.99484724 -0.9999686
#  -0.9953384  -0.9528251   0.9995063  -0.9999277  -0.41723654  0.51935804
#  -0.99759305 -0.99999666 -0.99999994 -0.9396985   0.9992409   0.84939003
#  -0.28030723  0.95485187  0.9963598  -0.910965    0.99997616  0.96737957
#  -0.8765117  -0.18591505 -0.8105124   0.9989246  -0.98506683  0.9999999
#   0.34563345  0.95964724 -0.99181044  0.9995369   0.89904433 -0.98382765
#  -0.6158973  -0.9961397  -0.9717155  -0.9474682  -0.7410803   0.9976271
#   0.99999815 -0.99999994 -0.9993072  -0.99999565  0.99988395  0.9999617
#  -0.99910665  0.9999991   0.99502623  0.9902567   0.99800503 -0.999994
#   0.9992447   0.473282    0.9999519  -0.9629989  -0.9557911  -0.9999992
#   0.9974116   0.87106574  0.54272527  0.99955606 -0.99954623 -0.54515016
#  -0.8131893   0.85693735  0.99918973  0.9998866  -0.9999965   0.99999976
#  -0.9470251  -0.9999879  -0.9999829   0.9966791  -0.9883714  -0.99982893
#   0.9999986  -0.96793973 -0.99996054  0.9999728   0.9997926  -0.99814653
#   0.99425036 -0.05907349  0.97231066  0.999831   -0.99999136 -0.985361
#  -0.98146397 -0.999953    0.9993844  -0.99968326 -0.99615175 -0.99813634
#   0.9833853  -0.98468983 -0.94031143  0.997617    0.96993464  0.9960141
#   0.999995    0.99740434 -0.9956915  -0.9999331  -0.999901    0.5323568
#  -0.99882585  0.9063282   0.8853059  -0.9999553  -0.85914123  0.57074964
#  -0.9663376  -0.99999887 -0.956132    0.9772355   0.99996537  0.999993
#   0.99850297  0.99706846]

# %%
embedding_weights = np.array(model.layers[0].get_weights()).reshape(16192,100)
simple_rnn_weights = model.layers[1].get_weights()

# %%
embedding_weights[0].shape

simple_rnn_weights[0].shape
simple_rnn_weights[1].shape
simple_rnn_weights[2].shape

kernel = simple_rnn_weights[0]
recurrent_kernel = simple_rnn_weights[1]
bias = simple_rnn_weights[2]
# Out:
# (16192, 100)
# (100, 128)
# (128, 128)
# (128,)

# %%
seed = [1, 2]
rnn_last_state = np.zeros(128)

for i in range(len(seed)):
    rnn_input = np.array(embedding_weights[seed[i]]).reshape(1,-1)
    # np.dot(rnn_last_state, recurrent_kernel)
    # np.dot(rnn_input, kernel) + np.dot(rnn_last_state, recurrent_kernel) + bias
    if i == 1:
#         np.dot(rnn_input, kernel)
        np.dot(rnn_last_state, recurrent_kernel)
    rnn_output = np.tanh(np.dot(rnn_input, kernel) + np.dot(rnn_last_state, recurrent_kernel) + bias)
#     rnn_output
    rnn_last_state = rnn_output
    
rnn_output
# Out:
# array([[-0.19871197,  0.41745028, -0.34474139, -1.10971409, -2.55533149,
#          1.42803591,  0.6097176 ,  0.85808208, -1.38965742, -0.01855767,
#         -1.26566144, -2.19317695,  2.55040328, -2.25840425, -0.5859573 ,
#          0.02375277,  3.87210029, -1.5169179 , -3.6983877 , -0.23823805,
#          3.5074762 ,  1.47142156,  0.0406416 ,  3.4254615 ,  0.47967848,
#          0.37693355, -1.03405159, -2.46427691, -0.74720811,  0.75434341,
#          0.15075813,  0.91013129, -1.62865896,  2.84496137, -0.14714996,
#          1.18228433, -3.03601694,  0.72553252,  0.03145215, -0.62544878,
#          0.3962952 ,  0.79409724,  0.77353565,  3.21586471, -1.43777011,
#          0.96422094,  4.29959125, -0.35596659, -3.08871807,  2.0995158 ,
#         -3.00105864,  0.67080632, -4.75841168,  0.81628265, -7.11455973,
#          2.26776   ,  1.48866826,  2.0494036 , -0.93816066, -2.14617125,
#          0.18780426, -0.355271  ,  1.53457386,  0.40104174,  0.92521768,
#          2.3397819 , -1.24999651,  2.7249429 , -0.13201467, -1.70001625,
#         -0.2405597 , -6.79070075, -2.58108538,  2.95884173,  0.07855455,
#          0.87946823,  2.20863577, -3.61566974, -3.98702562, -3.50086542,
#          2.19068233, -2.11710228,  0.49980112, -1.27775015,  5.39366165,
#          2.06981312,  1.96143346, -3.28563768, -0.26122918,  1.05725431,
#          0.58848901, -1.42629219,  2.13270152, -3.23102516, -2.81383016,
#         -0.53448306,  3.67806502,  0.60391169,  0.78137598,  0.82082281,
#         -0.01280848, -0.00834209, -2.23087745, -0.96443897,  2.23398546,
#          0.43434075, -4.5091176 , -0.16829654,  3.55441915,  3.70127041,
#         -0.23603467, -3.67121655,  0.55048443,  0.69287526, -3.50646365,
#          1.74222742,  0.55731678,  1.03106924,  2.04705601,  1.7562585 ,
#          0.65362306,  0.58408399, -0.25742055, -0.60677135, -1.6898399 ,
#         -0.78191448,  1.40544208, -0.34185541]])
# array([[ 0.9982106 , -0.96867131,  0.99517488,  0.99977043, -0.99832897,
#         -0.96210655,  0.99999906,  0.99999895, -0.99037884, -0.99403073,
#         -0.99999986, -0.99303087,  0.27003161, -0.99994589,  0.73167099,
#          0.99997336,  0.99822564,  0.79761757, -0.31039834, -0.58589771,
#         -0.99067353,  0.98561041, -0.99656653,  0.99927735,  0.2544966 ,
#          0.6042112 ,  0.99967793, -0.9488793 ,  0.83519773, -0.98701102,
#         -0.99996086,  0.94367716,  0.95175827,  0.99497095, -0.99292456,
#          0.99907122, -0.96776293,  0.9854117 , -0.9988922 , -0.91344262,
#         -0.3595444 ,  0.83359565, -0.9970186 , -0.49418385, -0.4116497 ,
#          0.76927467,  0.99611275,  0.99968999, -0.99999999, -0.36236135,
#         -0.99998713,  0.97511155, -0.99999999,  0.95130718, -0.99999455,
#          0.99955052,  0.98907375,  0.99999993,  0.97654438, -0.9968783 ,
#         -0.99988171,  0.7118891 , -0.99611497,  0.99861087, -0.96849475,
#          1.        , -0.9707406 ,  0.99433452,  0.99988983,  0.83363496,
#         -0.99976618, -0.99998835,  0.88375137,  0.3909594 ,  0.99788979,
#          0.62906053,  0.99995984, -0.99999995, -0.99999528, -0.99998626,
#          0.99966629, -0.99999998,  0.99999982, -0.99667857,  0.99992149,
#          0.89763513,  0.7155175 , -0.99976438,  0.49476315,  0.99997413,
#          0.21336391, -0.48036943, -0.5279039 , -0.84347017, -0.99137715,
#         -0.67326114,  0.98330569, -0.99741005, -0.96037564,  0.99985195,
#          0.81211963,  0.95188791, -0.99999858,  0.47795899,  0.93326416,
#          0.8735637 , -0.99908903,  0.99583045,  0.9998914 ,  0.99716244,
#          0.39706561, -0.99966057,  0.99985523, -0.98868861, -0.99898256,
#          0.99742464,  0.99999138,  0.99960968,  0.90353538, -0.99938575,
#          0.48781794,  0.99992271, -0.9880539 , -0.96361246, -0.99998978,
#          0.99999897,  0.98548853,  0.99916744]])

# %%
from keras.models import Model

model_name = 'train-embeddings-rnn-50'
model_dir = '../my_models/'
model = load_model(f'{model_dir}{model_name}.h5')

seed = [633, 5033, 21, 1, 4117, 30, 633, 3770, 12, 1, 22, 122, 4, 5478, 1, 44, 3, 25, 5696, 
 30, 5, 1, 4117, 30, 633, 4039, 7, 1, 22, 122, 3, 1, 810, 216, 8321, 10, 3188, 17, 14,
 2829, 741, 5, 366, 1, 4117, 30, 633, 182, 4039, 7]
# layer_name = 'simple_rnn_1'
layer_name = 'dense_1'
intermediate_layer_model = Model(inputs=model.input,
                                 outputs=model.get_layer(layer_name).output)
fc_output = intermediate_layer_model.predict(np.array(seed).reshape(1, -1))[0].astype(
                np.float32)

print(fc_output.shape, '\n', fc_output)
print(np.argmax(fc_output))
# Out:
# (16192,)
#  [6.7905109e-10 5.5151570e-01 2.0365700e-01 ... 5.2167232e-10 1.0485386e-08
#  4.9038400e-09]
# 1

# %%
fc_weights = model.layers[2].get_weights()
fc_weights[0].shape
fc_weights[1].shape
fc_kernel = fc_weights[0]
fc_bias = fc_weights[1]
# Out:
# (128, 16192)
# (16192,)

# %%
def softmax(X, theta = 1.0, axis = None):
    """
    Compute the softmax of each element along an axis of X.

    Parameters
    ----------
    X: ND-Array. Probably should be floats.
    theta (optional): float parameter, used as a multiplier
        prior to exponentiation. Default = 1.0
    axis (optional): axis to compute values along. Default is the
        first non-singleton axis.

    Returns an array the same size as X. The result will sum to 1
    along the specified axis.
    """

    # make X at least 2d
    y = np.atleast_2d(X)

    # find axis
    if axis is None:
        axis = next(j[0] for j in enumerate(y.shape) if j[1] > 1)

    # multiply y against the theta parameter,
    y = y * float(theta)

    # subtract the max for numerical stability
    y = y - np.expand_dims(np.max(y, axis = axis), axis)

    # exponentiate y
    y = np.exp(y)

    # take the sum along the specified axis
    ax_sum = np.expand_dims(np.sum(y, axis = axis), axis)

    # finally: divide elementwise
    p = y / ax_sum

    # flatten if X was 1D
    if len(X.shape) == 1: p = p.flatten()

    return p

# %%
fc_input = rnn_output
fc_input.shape
result = softmax(np.dot(fc_input, fc_kernel) + fc_bias)
result.shape
np.argmax(result)
# Out:
# (1, 128)
# (1, 16192)
# 9

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

BATCH_SIZE = 2048
model_name = 'train-embeddings-rnn-50'
model_dir = '../my_models/'

def make_callbacks(model_name, save=SAVE_MODEL):
    """Make list of callbacks for training"""
    callbacks = [EarlyStopping(monitor='val_loss', patience=5)]

    if save:
        callbacks.append(
            ModelCheckpoint(
                f'{model_dir}{model_name}.h5',
                save_best_only=True,
                save_weights_only=False))
    return callbacks


callbacks = make_callbacks(model_name)

# %%
def load_and_evaluate(model_name, return_model=False):
    """Load in a trained model and evaluate with log loss and accuracy"""

    model = load_model(f'{model_dir}{model_name}.h5')
    r = model.evaluate(X_valid, y_valid, batch_size=2048, verbose=1)

    valid_crossentropy = r[0]
    valid_accuracy = r[1]

    print(f'Cross Entropy: {round(valid_crossentropy, 4)}')
    print(f'Accuracy: {round(100 * valid_accuracy, 2)}%')

    if return_model:
        return model

# %%
model = load_and_evaluate(model_name, return_model=True)
# Out:
# 95569/95569 [==============================] - 9s 97us/step
# Cross Entropy: 4.6402
# Accuracy: 28.39%

# %%
from IPython.display import HTML


def header(text, color='black'):
    raw_html = f'<h1 style="color: {color};"><center>' + \
        str(text) + '</center></h1>'
    return raw_html


def box(text):
    raw_html = '<div style="border:1px inset black;padding:1em;font-size: 20px;">' + \
        str(text)+'</div>'
    return raw_html


def addContent(old_html, raw_html):
    old_html += raw_html
    return old_html

# %%
import random


def generate_output(model,
                    sequences,
                    training_length=50,
                    new_words=50,
                    diversity=1,
                    return_output=False,
                    n_gen=1):
    """Generate `new_words` words of output from a trained model and format into HTML."""

    # Choose a random sequence
    seq = random.choice(sequences)

    # Choose a random starting point
    seed_idx = random.randint(0, len(seq) - training_length - 10)
    # Ending index for seed
    end_idx = seed_idx + training_length

    gen_list = []

    for n in range(n_gen):
        # Extract the seed sequence
        seed = seq[seed_idx:end_idx]
        original_sequence = [idx_word[i] for i in seed]
        generated = seed[:] + ['#']

        # Find the actual entire sequence
        actual = generated[:] + seq[end_idx:end_idx + new_words]

        # Keep adding new words
        for i in range(new_words):

            # Make a prediction from the seed
            preds = model.predict(np.array(seed).reshape(1, -1))[0].astype(
                np.float64)

            # Diversify
            preds = np.log(preds) / diversity
            exp_preds = np.exp(preds)

            # Softmax
            preds = exp_preds / sum(exp_preds)

            # Choose the next word
            probas = np.random.multinomial(1, preds, 1)[0]

            next_idx = np.argmax(probas)

            # New seed adds on old word
            seed = seed[1:] + [next_idx]
            generated.append(next_idx)

        # Showing generated and actual abstract
        n = []

        for i in generated:
            n.append(idx_word.get(i, '< --- >'))

        gen_list.append(n)

    a = []

    for i in actual:
        a.append(idx_word.get(i, '< --- >'))

    a = a[training_length:]

    gen_list = [
        gen[training_length:training_length + len(a)] for gen in gen_list
    ]

    if return_output:
        return original_sequence, gen_list, a

    # HTML formatting
    seed_html = ''
    seed_html = addContent(seed_html, header(
        'Seed Sequence', color='darkblue'))
    seed_html = addContent(seed_html,
                           box(remove_spaces(' '.join(original_sequence))))

    gen_html = ''
    gen_html = addContent(gen_html, header('RNN Generated', color='darkred'))
    gen_html = addContent(gen_html, box(remove_spaces(' '.join(gen_list[0]))))

    a_html = ''
    a_html = addContent(a_html, header('Actual', color='darkgreen'))
    a_html = addContent(a_html, box(remove_spaces(' '.join(a))))

    return seed_html, gen_html, a_html

# %%
def remove_spaces(patent):
    """Remove spaces around punctuation"""
    patent = re.sub(r'\s+([.,;?])', r'\1', patent)

    return patent

# %%
seed_html, gen_html, a_html = generate_output(model, sequences,
                                              TRAINING_LENGTH)
HTML(seed_html)
HTML(gen_html)
HTML(a_html)
# Out:
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">and generates a single index by joining a plurality of indexes so as to apply the same to a neural network included in a defrost signal generating unit. The neural network generates a defrost on/off signal on the basis of inputted data. In addition, if feature amounts</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > are scaled into high dimension points, and interior information. Whether the triggering event and providing statistical sequences, input signal connection between the weights in the output first</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > are generated on the basis of the indexes by a feature detecting unit, the neural network generates the defrost on/off signal on the basis of the feature amounts.</div>

# %%
import random


def generate_next(model,
                    sequence,
                    ans,
                    training_length=50,
                    new_words=1,
                    diversity=1,
                    return_output=False,
                    return_idx=False,
                    n_gen=1):
    """Generate `new_words` words of output from a trained model and format into HTML."""
    """
    sequence: a tokenized sentence, e.g.[102,3,2314,3,...], with a length of training_length
    ans: the real next word
    """
    # Choose a random sequence
    seq = list(sequence)
    seed_idx = 0
    end_idx = training_length
    gen_list = []

    for n in range(n_gen):
        # Extract the seed sequence
        seed = seq[seed_idx:end_idx]
        original_sequence = [idx_word[i] for i in seed]
#         print(seed.shape, type(seed), type(['#']))
        generated = seed[:] + ['#']

        # Find the actual entire sequence
#         actual = generated[:] + seq[end_idx:end_idx + new_words]
        actual = generated[:] + [ans]
    
        # Keep adding new words
        for i in range(new_words):

            # Make a prediction from the seed
            preds = model.predict(np.array(seed).reshape(1, -1))[0].astype(
                np.float64)
#             print(preds.shape, "\n", preds)
            # Diversify
#             preds = np.log(preds) / diversity
#             exp_preds = np.exp(preds)
#             print(exp_preds.shape, exp_preds)

            # Softmax
#             preds = exp_preds / sum(exp_preds)

            # Choose the next word
#             probas = np.random.multinomial(1, preds, 1)[0]

#             next_idx = np.argmax(probas)
            next_idx = np.argmax(preds)

            # New seed adds on old word
            seed = seed[1:] + [next_idx]
            generated.append(next_idx)

        # Showing generated and actual abstract
        n = []

        for i in generated:
            n.append(idx_word.get(i, '< --- >'))

        gen_list.append(n)

    a = []

    for i in actual:
        a.append(idx_word.get(i, '< --- >'))

    a = a[training_length:]

    gen_list = [
        gen[training_length:training_length + len(a)] for gen in gen_list
    ]

    if return_output:
        if return_idx == False:
            return original_sequence, gen_list, a
        else:
#             print(original_sequence, gen_list, a)
#             print(original_sequence[0], gen_list[0][1], a[1])
            return [word_idx[ele] for ele in original_sequence], word_idx[gen_list[0][1]], word_idx[a[1]]
    # HTML formatting
    seed_html = ''
    seed_html = addContent(seed_html, header(
        'Seed Sequence', color='darkblue'))
    seed_html = addContent(seed_html,
                           box(remove_spaces(' '.join(original_sequence))))

    gen_html = ''
    gen_html = addContent(gen_html, header('RNN Generated', color='darkred'))
    gen_html = addContent(gen_html, box(remove_spaces(' '.join(gen_list[0]))))

    a_html = ''
    a_html = addContent(a_html, header('Actual', color='darkgreen'))
    a_html = addContent(a_html, box(remove_spaces(' '.join(a))))

    return seed_html, gen_html, a_html

# %%
X_valid.shape
y_valid.shape
# Out:
# (95569, 50)
# (95569, 16192)

# %%
X_valid[0]
# Out:
# array([ 633, 5033,   21,    1, 4117,   30,  633, 3770,   12,    1,   22,
#         122,    4, 5478,    1,   44,    3,   25, 5696,   30,    5,    1,
#        4117,   30,  633, 4039,    7,    1,   22,  122,    3,    1,  810,
#         216, 8321,   10, 3188,   17,   14, 2829,  741,    5,  366,    1,
#        4117,   30,  633,  182, 4039,    7])

# %%
for i in range(0, 10):
    # turn one-hot to index1
    # print(np.where(y_valid[1110]==1))
    seed_html, gen_html, a_html = generate_next(model, X_valid[i], np.where(y_valid[i]==1)[0][0],
                                                  training_length=TRAINING_LENGTH, new_words=1)
    HTML(seed_html)
    HTML(gen_html)
    HTML(a_html)

    seed, rnn_generate, actual = generate_next(model, X_valid[i], np.where(y_valid[i]==1)[0][0],
                                                  training_length=TRAINING_LENGTH, new_words=1, return_output=True, return_idx=True)
    print("seed:\n", seed)
    print("predicted: ", rnn_generate)
    print("actual: ", actual)
# Out:
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">path paired with the afferent signal path concerned in the output response. Under the control of which efferent signal, the afferent signal path contributing to the output response of the higher order cell-layer is affected by an excitatory effect, while the afferent signal path not contributing to</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > the</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > the</div>
# seed:
#  [633, 5033, 21, 1, 4117, 30, 633, 3770, 12, 1, 22, 122, 4, 5478, 1, 44, 3, 25, 5696, 30, 5, 1, 4117, 30, 633, 4039, 7, 1, 22, 122, 3, 1, 810, 216, 8321, 10, 3188, 17, 14, 2829, 741, 5, 366, 1, 4117, 30, 633, 182, 4039, 7]
# predicted:  1
# actual:  1
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">with preferred embodiments the systems are able to identify unknown objects when only a partial data set from the object is available. The system is robust and fast, utilizing parallel processing due to the massive interconnectivity of neural elements so that the image produced exhibits the properties of</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > the</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > super-resolution</div>
# seed:
#  [21, 609, 514, 1, 124, 16, 1276, 7, 360, 399, 250, 154, 320, 2, 752, 15, 42, 24, 1, 92, 10, 663, 4, 13, 20, 10, 1015, 6, 1273, 5, 425, 342, 46, 1220, 7, 1, 3468, 4911, 3, 9, 116, 151, 28, 1, 34, 450, 3165, 1, 622, 3]
# predicted:  1
# actual:  15452
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">network, including one or more of PA2 i) the number of neurons in a hidden layer PA2 ii) the number of hidden layers PA2 iii) the type of transfer functions in the layers and PA2 iv) the weights connecting the neurons PA1 e) whereby the artificial neural network is</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > trained</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > trained</div>
# seed:
#  [8, 5, 95, 33, 23, 74, 3, 6097, 4526, 1, 87, 3, 70, 12, 2, 185, 39, 6097, 5060, 1, 87, 3, 185, 190, 6097, 6765, 1, 222, 3, 661, 213, 12, 1, 190, 6, 6097, 9712, 1, 121, 1012, 1, 70, 1715, 5754, 1045, 1, 82, 9, 8, 10]
# predicted:  73
# actual:  73
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">in one of several directions from the initial state. Upon reaching another state, the model again instructs the object to move in one of several directions. These instructions continue until either: a) the object has completed a cycle by ending up back at a state it has</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > been</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > been</div>
# seed:
#  [12, 33, 3, 678, 1487, 24, 1, 351, 89, 4, 2198, 2178, 245, 89, 5, 1, 52, 1544, 4647, 1, 92, 7, 2129, 12, 33, 3, 678, 1487, 4, 467, 1286, 3929, 635, 7260, 2367, 1, 92, 84, 1791, 2, 739, 17, 2870, 638, 367, 35, 2, 89, 181, 84]
# predicted:  257
# actual:  257
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">and another set of samples characterized as not containing, the selected category of information content. This list of expressions is refined by applying correlation analysis to the samples or training data. Neural-network feed-forward techniques are then applied, again using a substantial training dataset, for adaptively</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > assigning</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > assigning</div>
# seed:
#  [6, 245, 42, 3, 277, 773, 27, 182, 497, 5, 1, 134, 441, 3, 50, 332, 4, 149, 962, 3, 2631, 10, 2428, 17, 432, 613, 129, 7, 1, 277, 23, 43, 15, 4, 7078, 1117, 276, 16, 88, 153, 5, 1544, 36, 2, 2907, 43, 2529, 5, 11, 1249]
# predicted:  1805
# actual:  1805
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">the radar signal. The detector includes a time-frequency analyzer which transforms the target signals into a time-frequency image representation (TFR). In a preferred embodiment, the detector can include a wavelet packet transformer (WPT) for extracting time-frequency localized information from the TFR in the form of feature set</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- >,</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > constructed</div>
# seed:
#  [1, 1272, 30, 4, 13, 374, 41, 2, 2802, 708, 25, 1396, 1, 132, 51, 69, 2, 2802, 34, 281, 12064, 4, 64, 2, 609, 166, 5, 1, 374, 40, 142, 2, 713, 764, 2733, 12065, 11, 494, 2802, 2890, 50, 24, 1, 12066, 12, 1, 165, 3, 80, 42]
# predicted:  5
# actual:  534
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">adding weights to signals on the internal data output lines in the corresponding group and outputting the weighted signals, and an addition circuit for outputting a total sum of the outputs of those weighting elements. The internal data output lines are arranged to form pairs and the addition</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > circuit</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > circuit</div>
# seed:
#  [1820, 121, 7, 51, 29, 1, 322, 15, 22, 443, 12, 1, 79, 244, 6, 538, 1, 305, 51, 5, 6, 14, 547, 65, 11, 538, 2, 779, 484, 3, 1, 103, 3, 455, 307, 116, 4, 13, 322, 15, 22, 443, 16, 546, 7, 165, 681, 6, 1, 547]
# predicted:  65
# actual:  65
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">heated to a temperature above the reactor temperature with a third laser beam. The rate at which the sample/substance temperature relaxes to the temperature of the reactor is measured. This additional heating of the sample/substance is preferably achieved by a laser focused on the sample/substance itself. All</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > the</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > of</div>
# seed:
#  [4479, 7, 2, 256, 1029, 1, 2165, 256, 21, 2, 376, 1152, 890, 4, 13, 252, 35, 25, 1, 5872, 256, 12664, 7, 1, 256, 3, 1, 2165, 10, 231, 4, 149, 605, 2627, 3, 1, 5872, 10, 423, 754, 17, 2, 1152, 3660, 29, 1, 5872, 1222, 4, 1509]
# predicted:  1
# actual:  3
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">cycle analysis program as well as by directed experiments. An artificial neural network (ANN) is trained by presenting the measurement values and the blade temp values. In a hybrid approach, 5 measured values are utilized. A subset of 4 parameter values is used for training the</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > neural</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > ANN</div>
# seed:
#  [739, 129, 303, 27, 335, 27, 17, 892, 5615, 4, 76, 82, 9, 8, 802, 10, 73, 17, 2083, 1, 382, 48, 6, 1, 3568, 8876, 48, 4, 64, 2, 839, 676, 5, 3845, 231, 48, 16, 513, 4, 18, 615, 3, 2676, 105, 48, 10, 54, 11, 43, 1]
# predicted:  9
# actual:  439
# <h1 style="color: darkblue;"><center>Seed Sequence</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">classification criteria for a pattern class is stored distributively in the neural network in two aspects. First, it manifests itself as one or more levels of templates, each of which represents a fuzzily unique perspective of the pattern class. Second, the template at each level</div>
# <h1 style="color: darkred;"><center>RNN Generated</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > of</div>
# <h1 style="color: darkgreen;"><center>Actual</center></h1><div style="border:1px inset black;padding:1em;font-size: 20px;">< --- > is</div>
# seed:
#  [156, 1474, 11, 2, 59, 315, 10, 136, 8723, 12, 1, 9, 8, 12, 157, 2122, 4, 1443, 5, 181, 8724, 1222, 27, 33, 23, 74, 436, 3, 2111, 5, 32, 3, 25, 555, 2, 8725, 1160, 6933, 3, 1, 59, 315, 4, 4295, 5, 1, 568, 35, 32, 225]
# predicted:  3
# actual:  10

# %%
# save results

org_seq = []
rnn_result = []
actual_result= []

for i in range(0, 1000):

    seed, rnn_generate, actual = generate_next(model, X_valid[i], np.where(y_valid[i]==1)[0][0],
                                                  training_length=TRAINING_LENGTH, new_words=1, return_output=True, return_idx=True)
    print("sentence {}:".format(i) )
#     print("seed:\n", seed)
    print("predicted: ", rnn_generate)
    print("actual: ", actual, '\n')
    org_seq.append(seed)
    rnn_result.append(rnn_generate)
    actual_result.append(actual)
    

org_seq = np.array(org_seq, dtype=int)
rnn_result = np.array(rnn_result, dtype=int)
actual_result = np.array(actual_result, dtype=int)

type(org_seq[0][0])

# np.savetxt("./C_test_set/org_seq.txt", org_seq)
# np.savetxt("./C_test_set/rnn_result.txt", rnn_result)
# np.savetxt("./C_test_set/actual_result.txt", actual_result)

np.save("./C_test_set/org_seq", org_seq)
np.save("./C_test_set/rnn_result", rnn_result)
np.save("./C_test_set/actual_result", actual_result)
# Out:
# sentence 0:
# predicted:  1
# actual:  1
#
# sentence 1:
# predicted:  1
# actual:  15452
#
# sentence 2:
# predicted:  73
# actual:  73
#
# sentence 3:
# predicted:  257
# actual:  257
#
# sentence 4:
# predicted:  1805
# actual:  1805
#
# sentence 5:
# predicted:  5
# actual:  534
#
# sentence 6:
# predicted:  65
# actual:  65
#
# sentence 7:
# predicted:  1
# actual:  3
#
# sentence 8:
# predicted:  9
# actual:  439
#
# sentence 9:
# predicted:  3
# actual:  10
#
# sentence 10:
# predicted:  143
# actual:  479
#
# sentence 11:
# predicted:  6
# actual:  12
#
# sentence 12:
# predicted:  3
# actual:  3
#
# sentence 13:
# predicted:  198
# actual:  538
#
# sentence 14:
# predicted:  53
# actual:  145
#
# sentence 15:
# predicted:  39
# actual:  8
#
# sentence 16:
# predicted:  7
# actual:  29
#
# sentence 17:
# predicted:  333
# actual:  333
#
# sentence 18:
# predicted:  9
# actual:  611
#
# sentence 19:
# predicted:  1
# actual:  99
#
# sentence 20:
# predicted:  1
# actual:  1
#
# sentence 21:
# predicted:  16
# actual:  530
#
# sentence 22:
# predicted:  1
# actual:  143
#
# sentence 23:
# predicted:  2637
# actual:  456
#
# sentence 24:
# predicted:  1
# actual:  43
#
# sentence 25:
# predicted:  1
# actual:  2
#
# sentence 26:
# predicted:  9
# actual:  288
#
# sentence 27:
# predicted:  4
# actual:  4
#
# sentence 28:
# predicted:  101
# actual:  15
#
# sentence 29:
# predicted:  1367
# actual:  1367
#
# sentence 30:
# predicted:  133
# actual:  133
#
# sentence 31:
# predicted:  1
# actual:  85
#
# sentence 32:
# predicted:  73
# actual:  73
#
# sentence 33:
# predicted:  1
# actual:  188
#
# sentence 34:
# predicted:  2
# actual:  85
#
# sentence 35:
# predicted:  1
# actual:  1
#
# sentence 36:
# predicted:  12
# actual:  624
#
# sentence 37:
# predicted:  5460
# actual:  921
#
# sentence 38:
# predicted:  22
# actual:  1
#
# sentence 39:
# predicted:  9
# actual:  20
#
# sentence 40:
# predicted:  16
# actual:  29
#
# sentence 41:
# predicted:  9
# actual:  190
#
# sentence 42:
# predicted:  1
# actual:  188
#
# sentence 43:
# predicted:  122
# actual:  30
#
# sentence 44:
# predicted:  1
# actual:  1
#
# sentence 45:
# predicted:  4148
# actual:  4148
#
# sentence 46:
# predicted:  405
# actual:  5
#
# sentence 47:
# predicted:  3
# actual:  6
#
# sentence 48:
# predicted:  7
# actual:  5
#
# sentence 49:
# predicted:  3
# actual:  635
#
# sentence 50:
# predicted:  9
# actual:  108
#
# sentence 51:
# predicted:  8364
# actual:  8364
#
# sentence 52:
# predicted:  4
# actual:  25
#
# sentence 53:
# predicted:  384
# actual:  136
#
# sentence 54:
# predicted:  9
# actual:  1983
#
# sentence 55:
# predicted:  4
# actual:  4
#
# sentence 56:
# predicted:  17
# actual:  4
#
# sentence 57:
# predicted:  111
# actual:  140
#
# sentence 58:
# predicted:  9
# actual:  313
#
# sentence 59:
# predicted:  915
# actual:  27
#
# sentence 60:
# predicted:  301
# actual:  2834
#
# sentence 61:
# predicted:  99
# actual:  9
#
# sentence 62:
# predicted:  1407
# actual:  3
#
# sentence 63:
# predicted:  42
# actual:  782
#
# sentence 64:
# predicted:  13
# actual:  13
#
# sentence 65:
# predicted:  6
# actual:  581
#
# sentence 66:
# predicted:  10
# actual:  68
#
# sentence 67:
# predicted:  1
# actual:  215
#
# sentence 68:
# predicted:  632
# actual:  449
#
# sentence 69:
# predicted:  7
# actual:  7
#
# sentence 70:
# predicted:  2
# actual:  1
#
# sentence 71:
# predicted:  1
# actual:  1
#
# sentence 72:
# predicted:  10
# actual:  41
#
# sentence 73:
# predicted:  1
# actual:  1401
#
# sentence 74:
# predicted:  1
# actual:  2
#
# sentence 75:
# predicted:  9114
# actual:  9114
#
# sentence 76:
# predicted:  2
# actual:  8939
#
# sentence 77:
# predicted:  7
# actual:  1
#
# sentence 78:
# predicted:  3748
# actual:  1
#
# sentence 79:
# predicted:  155
# actual:  140
#
# sentence 80:
# predicted:  10
# actual:  1359
#
# sentence 81:
# predicted:  4
# actual:  3
#
# sentence 82:
# predicted:  10
# actual:  395
#
# sentence 83:
# predicted:  5
# actual:  6
#
# sentence 84:
# predicted:  2050
# actual:  1336
#
# sentence 85:
# predicted:  2
# actual:  21
#
# sentence 86:
# predicted:  1
# actual:  1
#
# sentence 87:
# predicted:  4
# actual:  4
#
# sentence 88:
# predicted:  4
# actual:  110
#
# sentence 89:
# predicted:  185
# actual:  152
#
# sentence 90:
# predicted:  3
# actual:  3
#
# sentence 91:
# predicted:  1
# actual:  2
#
# sentence 92:
# predicted:  105
# actual:  6
#
# sentence 93:
# predicted:  9
# actual:  357
#
# sentence 94:
# predicted:  37
# actual:  86
#
# sentence 95:
# predicted:  2
# actual:  48
#
# sentence 96:
# predicted:  2
# actual:  14
#
# sentence 97:
# predicted:  13
# actual:  13
#
# sentence 98:
# predicted:  37
# actual:  273
#
# sentence 99:
# predicted:  405
# actual:  25
#
# sentence 100:
# predicted:  1591
# actual:  15
#
# sentence 101:
# predicted:  2
# actual:  1
#
# sentence 102:
# predicted:  5
# actual:  11
#
# sentence 103:
# predicted:  1
# actual:  1
#
# sentence 104:
# predicted:  6
# actual:  6421
#
# sentence 105:
# predicted:  4
# actual:  6
#
# sentence 106:
# predicted:  1
# actual:  2
#
# sentence 107:
# predicted:  165
# actual:  471
#
# sentence 108:
# predicted:  51
# actual:  51
#
# sentence 109:
# predicted:  1
# actual:  2085
#
# sentence 110:
# predicted:  7252
# actual:  90
#
# sentence 111:
# predicted:  4
# actual:  4
#
# sentence 112:
# predicted:  1
# actual:  1
#
# sentence 113:
# predicted:  13
# actual:  13
#
# sentence 114:
# predicted:  3
# actual:  3
#
# sentence 115:
# predicted:  1265
# actual:  80
#
# sentence 116:
# predicted:  1
# actual:  1
#
# sentence 117:
# predicted:  12
# actual:  4
#
# sentence 118:
# predicted:  9352
# actual:  9350
#
# sentence 119:
# predicted:  439
# actual:  4288
#
# sentence 120:
# predicted:  2
# actual:  14
#
# sentence 121:
# predicted:  1
# actual:  1
#
# sentence 122:
# predicted:  1
# actual:  887
#
# sentence 123:
# predicted:  1345
# actual:  1345
#
# sentence 124:
# predicted:  9
# actual:  86
#
# sentence 125:
# predicted:  33
# actual:  33
#
# sentence 126:
# predicted:  72
# actual:  241
#
# sentence 127:
# predicted:  10
# actual:  209
#
# sentence 128:
# predicted:  5660
# actual:  350
#
# sentence 129:
# predicted:  1
# actual:  2
#
# sentence 130:
# predicted:  4
# actual:  6
#
# sentence 131:
# predicted:  15
# actual:  272
#
# sentence 132:
# predicted:  1
# actual:  14648
#
# sentence 133:
# predicted:  1
# actual:  1
#
# sentence 134:
# predicted:  1
# actual:  911
#
# sentence 135:
# predicted:  3
# actual:  3
#
# sentence 136:
# predicted:  10
# actual:  15
#
# sentence 137:
# predicted:  3
# actual:  3
#
# sentence 138:
# predicted:  2
# actual:  155
#
# sentence 139:
# predicted:  15
# actual:  30
#
# sentence 140:
# predicted:  6
# actual:  6
#
# sentence 141:
# predicted:  13802
# actual:  3519
#
# sentence 142:
# predicted:  4
# actual:  5
#
# sentence 143:
# predicted:  1
# actual:  1
#
# sentence 144:
# predicted:  9
# actual:  1112
#
# sentence 145:
# predicted:  4
# actual:  25
#
# sentence 146:
# predicted:  88
# actual:  96
#
# sentence 147:
# predicted:  129
# actual:  2126
#
# sentence 148:
# predicted:  87
# actual:  53
#
# sentence 149:
# predicted:  4
# actual:  5
#
# sentence 150:
# predicted:  1
# actual:  2
#
# sentence 151:
# predicted:  167
# actual:  844
#
# sentence 152:
# predicted:  9
# actual:  776
#
# sentence 153:
# predicted:  16
# actual:  928
#
# sentence 154:
# predicted:  6
# actual:  29
#
# sentence 155:
# predicted:  23
# actual:  40
#
# sentence 156:
# predicted:  23
# actual:  4
#
# sentence 157:
# predicted:  5
# actual:  46
#
# sentence 158:
# predicted:  9
# actual:  2664
#
# sentence 159:
# predicted:  11
# actual:  11
#
# sentence 160:
# predicted:  65
# actual:  123
#
# sentence 161:
# predicted:  42
# actual:  167
#
# sentence 162:
# predicted:  1371
# actual:  6
#
# sentence 163:
# predicted:  19
# actual:  1248
#
# sentence 164:
# predicted:  5
# actual:  5
#
# sentence 165:
# predicted:  9
# actual:  22
#
# sentence 166:
# predicted:  165
# actual:  70
#
# sentence 167:
# predicted:  9
# actual:  327
#
# sentence 168:
# predicted:  13
# actual:  13
#
# sentence 169:
# predicted:  1
# actual:  1
#
# sentence 170:
# predicted:  5
# actual:  35
#
# sentence 171:
# predicted:  54
# actual:  54
#
# sentence 172:
# predicted:  1
# actual:  1
#
# sentence 173:
# predicted:  2
# actual:  2
#
# sentence 174:
# predicted:  1
# actual:  27
#
# sentence 175:
# predicted:  75
# actual:  75
#
# sentence 176:
# predicted:  22
# actual:  571
#
# sentence 177:
# predicted:  41
# actual:  3
#
# sentence 178:
# predicted:  6
# actual:  23
#
# sentence 179:
# predicted:  3
# actual:  3
#
# sentence 180:
# predicted:  2
# actual:  2
#
# sentence 181:
# predicted:  4598
# actual:  402
#
# sentence 182:
# predicted:  1
# actual:  1
#
# sentence 183:
# predicted:  12
# actual:  12
#
# sentence 184:
# predicted:  6070
# actual:  1239
#
# sentence 185:
# predicted:  2
# actual:  14
#
# sentence 186:
# predicted:  2
# actual:  2
#
# sentence 187:
# predicted:  2
# actual:  3523
#
# sentence 188:
# predicted:  72
# actual:  213
#
# sentence 189:
# predicted:  5
# actual:  3
#
# sentence 190:
# predicted:  7
# actual:  647
#
# sentence 191:
# predicted:  2
# actual:  157
#
# sentence 192:
# predicted:  869
# actual:  4
#
# sentence 193:
# predicted:  1
# actual:  28
#
# sentence 194:
# predicted:  3
# actual:  3
#
# sentence 195:
# predicted:  1
# actual:  1
#
# sentence 196:
# predicted:  9
# actual:  31
#
# sentence 197:
# predicted:  16
# actual:  3
#
# sentence 198:
# predicted:  12
# actual:  12
#
# sentence 199:
# predicted:  1
# actual:  32
#
# sentence 200:
# predicted:  3
# actual:  3
#
# sentence 201:
# predicted:  17
# actual:  7
#
# sentence 202:
# predicted:  51
# actual:  201
#
# sentence 203:
# predicted:  74
# actual:  74
#
# sentence 204:
# predicted:  9
# actual:  671
#
# sentence 205:
# predicted:  13
# actual:  904
#
# sentence 206:
# predicted:  9
# actual:  1082
#
# sentence 207:
# predicted:  10
# actual:  148
#
# sentence 208:
# predicted:  258
# actual:  682
#
# sentence 209:
# predicted:  44
# actual:  557
#
# sentence 210:
# predicted:  7
# actual:  42
#
# sentence 211:
# predicted:  3
# actual:  6
#
# sentence 212:
# predicted:  3
# actual:  54
# sentence 213:
# predicted:  1
# actual:  14
#
# sentence 214:
# predicted:  1
# actual:  566
#
# sentence 215:
# predicted:  4
# actual:  5
#
# sentence 216:
# predicted:  1
# actual:  1
#
# sentence 217:
# predicted:  5
# actual:  2731
#
# sentence 218:
# predicted:  6990
# actual:  6990
#
# sentence 219:
# predicted:  1
# actual:  4106
#
# sentence 220:
# predicted:  1
# actual:  1
#
# sentence 221:
# predicted:  7
# actual:  171
#
# sentence 222:
# predicted:  11
# actual:  3
#
# sentence 223:
# predicted:  9
# actual:  2259
#
# sentence 224:
# predicted:  257
# actual:  2
#
# sentence 225:
# predicted:  5
# actual:  51
#
# sentence 226:
# predicted:  1
# actual:  14
#
# sentence 227:
# predicted:  4
# actual:  10
#
# sentence 228:
# predicted:  1
# actual:  1
#
# sentence 229:
# predicted:  9
# actual:  2016
#
# sentence 230:
# predicted:  6
# actual:  6
#
# sentence 231:
# predicted:  17
# actual:  29
#
# sentence 232:
# predicted:  6
# actual:  6
#
# sentence 233:
# predicted:  5
# actual:  5
#
# sentence 234:
# predicted:  54
# actual:  284
#
# sentence 235:
# predicted:  62
# actual:  62
#
# sentence 236:
# predicted:  10
# actual:  10
#
# sentence 237:
# predicted:  1923
# actual:  1923
#
# sentence 238:
# predicted:  33
# actual:  33
#
# sentence 239:
# predicted:  3
# actual:  25
#
# sentence 240:
# predicted:  130
# actual:  130
#
# sentence 241:
# predicted:  4
# actual:  1045
#
# sentence 242:
# predicted:  1
# actual:  4255
#
# sentence 243:
# predicted:  4
# actual:  694
#
# sentence 244:
# predicted:  4
# actual:  4
#
# sentence 245:
# predicted:  182
# actual:  54
#
# sentence 246:
# predicted:  2
# actual:  8219
#
# sentence 247:
# predicted:  4
# actual:  6
#
# sentence 248:
# predicted:  13
# actual:  13
#
# sentence 249:
# predicted:  107
# actual:  167
#
# sentence 250:
# predicted:  3922
# actual:  2381
#
# sentence 251:
# predicted:  2388
# actual:  5421
#
# sentence 252:
# predicted:  16
# actual:  243
#
# sentence 253:
# predicted:  1
# actual:  56
#
# sentence 254:
# predicted:  9
# actual:  170
#
# sentence 255:
# predicted:  3
# actual:  357
#
# sentence 256:
# predicted:  1
# actual:  1
#
# sentence 257:
# predicted:  2
# actual:  2
#
# sentence 258:
# predicted:  4
# actual:  25
#
# sentence 259:
# predicted:  9
# actual:  9
#
# sentence 260:
# predicted:  4
# actual:  4
#
# sentence 261:
# predicted:  2
# actual:  687
#
# sentence 262:
# predicted:  10
# actual:  542
#
# sentence 263:
# predicted:  53
# actual:  89
#
# sentence 264:
# predicted:  10
# actual:  970
#
# sentence 265:
# predicted:  30
# actual:  30
#
# sentence 266:
# predicted:  16
# actual:  6
#
# sentence 267:
# predicted:  4
# actual:  96
#
# sentence 268:
# predicted:  1
# actual:  822
#
# sentence 269:
# predicted:  54
# actual:  655
#
# sentence 270:
# predicted:  5
# actual:  69
#
# sentence 271:
# predicted:  1558
# actual:  15539
#
# sentence 272:
# predicted:  13
# actual:  646
#
# sentence 273:
# predicted:  54
# actual:  2202
#
# sentence 274:
# predicted:  210
# actual:  831
#
# sentence 275:
# predicted:  15
# actual:  5
#
# sentence 276:
# predicted:  1
# actual:  43
#
# sentence 277:
# predicted:  108
# actual:  108
#
# sentence 278:
# predicted:  24
# actual:  161
#
# sentence 279:
# predicted:  357
# actual:  357
#
# sentence 280:
# predicted:  10
# actual:  45
#
# sentence 281:
# predicted:  4
# actual:  17
#
# sentence 282:
# predicted:  159
# actual:  4
#
# sentence 283:
# predicted:  4
# actual:  7292
#
# sentence 284:
# predicted:  1
# actual:  1
#
# sentence 285:
# predicted:  1
# actual:  1
#
# sentence 286:
# predicted:  31
# actual:  744
#
# sentence 287:
# predicted:  81
# actual:  81
#
# sentence 288:
# predicted:  70
# actual:  15
#
# sentence 289:
# predicted:  227
# actual:  90
#
# sentence 290:
# predicted:  1
# actual:  1
#
# sentence 291:
# predicted:  3
# actual:  3
#
# sentence 292:
# predicted:  4414
# actual:  365
#
# sentence 293:
# predicted:  1
# actual:  1793
#
# sentence 294:
# predicted:  1
# actual:  9576
#
# sentence 295:
# predicted:  54
# actual:  711
#
# sentence 296:
# predicted:  1
# actual:  86
#
# sentence 297:
# predicted:  7
# actual:  7
#
# sentence 298:
# predicted:  5
# actual:  348
#
# sentence 299:
# predicted:  5953
# actual:  5953
#
# sentence 300:
# predicted:  1
# actual:  1
#
# sentence 301:
# predicted:  3
# actual:  12
#
# sentence 302:
# predicted:  22
# actual:  1487
#
# sentence 303:
# predicted:  6
# actual:  96
#
# sentence 304:
# predicted:  37
# actual:  1546
#
# sentence 305:
# predicted:  1
# actual:  2
#
# sentence 306:
# predicted:  15629
# actual:  256
#
# sentence 307:
# predicted:  9
# actual:  2924
#
# sentence 308:
# predicted:  58
# actual:  58
#
# sentence 309:
# predicted:  2
# actual:  290
#
# sentence 310:
# predicted:  1
# actual:  2
#
# sentence 311:
# predicted:  11
# actual:  667
#
# sentence 312:
# predicted:  1
# actual:  1
#
# sentence 313:
# predicted:  4352
# actual:  43
#
# sentence 314:
# predicted:  572
# actual:  1363
#
# sentence 315:
# predicted:  1
# actual:  1
#
# sentence 316:
# predicted:  48
# actual:  11
#
# sentence 317:
# predicted:  1
# actual:  1
#
# sentence 318:
# predicted:  5
# actual:  195
#
# sentence 319:
# predicted:  4
# actual:  4
#
# sentence 320:
# predicted:  3
# actual:  333
#
# sentence 321:
# predicted:  3
# actual:  5
#
# sentence 322:
# predicted:  1
# actual:  748
#
# sentence 323:
# predicted:  7
# actual:  29
#
# sentence 324:
# predicted:  5
# actual:  5
#
# sentence 325:
# predicted:  9
# actual:  42
#
# sentence 326:
# predicted:  5
# actual:  6
#
# sentence 327:
# predicted:  1
# actual:  508
#
# sentence 328:
# predicted:  443
# actual:  443
#
# sentence 329:
# predicted:  138
# actual:  20
#
# sentence 330:
# predicted:  2
# actual:  33
#
# sentence 331:
# predicted:  4
# actual:  4
#
# sentence 332:
# predicted:  114
# actual:  404
#
# sentence 333:
# predicted:  2
# actual:  4284
#
# sentence 334:
# predicted:  22
# actual:  994
#
# sentence 335:
# predicted:  1388
# actual:  54
#
# sentence 336:
# predicted:  2
# actual:  22
#
# sentence 337:
# predicted:  111
# actual:  5645
#
# sentence 338:
# predicted:  4
# actual:  865
#
# sentence 339:
# predicted:  1
# actual:  1
#
# sentence 340:
# predicted:  3
# actual:  2745
#
# sentence 341:
# predicted:  44
# actual:  5
#
# sentence 342:
# predicted:  1
# actual:  1
#
# sentence 343:
# predicted:  5
# actual:  13971
#
# sentence 344:
# predicted:  30
# actual:  25
#
# sentence 345:
# predicted:  1
# actual:  1
#
# sentence 346:
# predicted:  1
# actual:  859
#
# sentence 347:
# predicted:  2
# actual:  191
#
# sentence 348:
# predicted:  70
# actual:  3549
#
# sentence 349:
# predicted:  1700
# actual:  98
#
# sentence 350:
# predicted:  1
# actual:  1
#
# sentence 351:
# predicted:  52
# actual:  2410
#
# sentence 352:
# predicted:  9
# actual:  351
#
# sentence 353:
# predicted:  51
# actual:  961
#
# sentence 354:
# predicted:  1538
# actual:  1
#
# sentence 355:
# predicted:  82
# actual:  82
#
# sentence 356:
# predicted:  37
# actual:  37
#
# sentence 357:
# predicted:  6
# actual:  432
#
# sentence 358:
# predicted:  3
# actual:  217
#
# sentence 359:
# predicted:  217
# actual:  47
#
# sentence 360:
# predicted:  13
# actual:  886
#
# sentence 361:
# predicted:  17
# actual:  6
#
# sentence 362:
# predicted:  262
# actual:  297
#
# sentence 363:
# predicted:  73
# actual:  12
#
# sentence 364:
# predicted:  37
# actual:  624
#
# sentence 365:
# predicted:  43
# actual:  341
#
# sentence 366:
# predicted:  9
# actual:  38
#
# sentence 367:
# predicted:  185
# actual:  4146
#
# sentence 368:
# predicted:  1
# actual:  1
#
# sentence 369:
# predicted:  1453
# actual:  3094
#
# sentence 370:
# predicted:  15
# actual:  51
#
# sentence 371:
# predicted:  7
# actual:  7
#
# sentence 372:
# predicted:  53
# actual:  355
#
# sentence 373:
# predicted:  7
# actual:  7
#
# sentence 374:
# predicted:  6
# actual:  1218
#
# sentence 375:
# predicted:  38
# actual:  564
#
# sentence 376:
# predicted:  2047
# actual:  2047
#
# sentence 377:
# predicted:  12
# actual:  12
#
# sentence 378:
# predicted:  6
# actual:  256
#
# sentence 379:
# predicted:  3
# actual:  4
#
# sentence 380:
# predicted:  302
# actual:  654
#
# sentence 381:
# predicted:  274
# actual:  274
#
# sentence 382:
# predicted:  58
# actual:  58
#
# sentence 383:
# predicted:  5
# actual:  4
#
# sentence 384:
# predicted:  16
# actual:  2
#
# sentence 385:
# predicted:  11
# actual:  1448
#
# sentence 386:
# predicted:  74
# actual:  512
#
# sentence 387:
# predicted:  7
# actual:  27
#
# sentence 388:
# predicted:  10
# actual:  10
#
# sentence 389:
# predicted:  9
# actual:  222
#
# sentence 390:
# predicted:  2
# actual:  1
#
# sentence 391:
# predicted:  1
# actual:  1
#
# sentence 392:
# predicted:  4
# actual:  5
#
# sentence 393:
# predicted:  3129
# actual:  40
#
# sentence 394:
# predicted:  2
# actual:  2
#
# sentence 395:
# predicted:  5
# actual:  10
#
# sentence 396:
# predicted:  4
# actual:  4
#
# sentence 397:
# predicted:  4
# actual:  4
#
# sentence 398:
# predicted:  2
# actual:  2600
#
# sentence 399:
# predicted:  22
# actual:  22
#
# sentence 400:
# predicted:  2091
# actual:  2091
#
# sentence 401:
# predicted:  1
# actual:  1
#
# sentence 402:
# predicted:  5
# actual:  5
#
# sentence 403:
# predicted:  30
# actual:  44
#
# sentence 404:
# predicted:  20
# actual:  20
#
# sentence 405:
# predicted:  104
# actual:  3
#
# sentence 406:
# predicted:  4
# actual:  4
#
# sentence 407:
# predicted:  1
# actual:  32
#
# sentence 408:
# predicted:  9
# actual:  1934
#
# sentence 409:
# predicted:  112
# actual:  112
#
# sentence 410:
# predicted:  120
# actual:  1294
#
# sentence 411:
# predicted:  4
# actual:  66
#
# sentence 412:
# predicted:  10
# actual:  41
#
# sentence 413:
# predicted:  1
# actual:  1
#
# sentence 414:
# predicted:  8
# actual:  8
#
# sentence 415:
# predicted:  70
# actual:  1629
#
# sentence 416:
# predicted:  5
# actual:  400
#
# sentence 417:
# predicted:  1
# actual:  1
#
# sentence 418:
# predicted:  10
# actual:  720
#
# sentence 419:
# predicted:  6
# actual:  5290
#
# sentence 420:
# predicted:  2555
# actual:  251
#
# sentence 421:
# predicted:  5
# actual:  5
# sentence 422:
# predicted:  5
# actual:  5
#
# sentence 423:
# predicted:  41
# actual:  1511
#
# sentence 424:
# predicted:  147
# actual:  147
#
# sentence 425:
# predicted:  257
# actual:  189
#
# sentence 426:
# predicted:  1
# actual:  9
#
# sentence 427:
# predicted:  54
# actual:  78
#
# sentence 428:
# predicted:  22
# actual:  1206
#
# sentence 429:
# predicted:  258
# actual:  258
#
# sentence 430:
# predicted:  9
# actual:  114
#
# sentence 431:
# predicted:  29
# actual:  29
#
# sentence 432:
# predicted:  166
# actual:  166
#
# sentence 433:
# predicted:  2263
# actual:  17
#
# sentence 434:
# predicted:  4
# actual:  161
#
# sentence 435:
# predicted:  4
# actual:  5
#
# sentence 436:
# predicted:  796
# actual:  9
#
# sentence 437:
# predicted:  21
# actual:  265
#
# sentence 438:
# predicted:  7
# actual:  7
#
# sentence 439:
# predicted:  6
# actual:  6
#
# sentence 440:
# predicted:  70
# actual:  277
#
# sentence 441:
# predicted:  5
# actual:  4
#
# sentence 442:
# predicted:  6
# actual:  24
#
# sentence 443:
# predicted:  6
# actual:  1660
#
# sentence 444:
# predicted:  3
# actual:  30
#
# sentence 445:
# predicted:  4
# actual:  4
#
# sentence 446:
# predicted:  13
# actual:  1174
#
# sentence 447:
# predicted:  1
# actual:  44
#
# sentence 448:
# predicted:  16
# actual:  11
#
# sentence 449:
# predicted:  178
# actual:  22
#
# sentence 450:
# predicted:  3
# actual:  8691
#
# sentence 451:
# predicted:  329
# actual:  329
#
# sentence 452:
# predicted:  73
# actual:  73
#
# sentence 453:
# predicted:  1
# actual:  877
#
# sentence 454:
# predicted:  22
# actual:  3559
#
# sentence 455:
# predicted:  22
# actual:  2
#
# sentence 456:
# predicted:  1
# actual:  804
#
# sentence 457:
# predicted:  1
# actual:  1551
#
# sentence 458:
# predicted:  23
# actual:  10
#
# sentence 459:
# predicted:  6
# actual:  48
#
# sentence 460:
# predicted:  1
# actual:  2
#
# sentence 461:
# predicted:  7
# actual:  758
#
# sentence 462:
# predicted:  1
# actual:  1
#
# sentence 463:
# predicted:  61
# actual:  61
#
# sentence 464:
# predicted:  198
# actual:  3617
#
# sentence 465:
# predicted:  2
# actual:  1
#
# sentence 466:
# predicted:  4
# actual:  5391
#
# sentence 467:
# predicted:  10
# actual:  468
#
# sentence 468:
# predicted:  4
# actual:  276
#
# sentence 469:
# predicted:  10054
# actual:  104
#
# sentence 470:
# predicted:  2
# actual:  141
#
# sentence 471:
# predicted:  7787
# actual:  112
#
# sentence 472:
# predicted:  16
# actual:  601
#
# sentence 473:
# predicted:  6
# actual:  6
#
# sentence 474:
# predicted:  9902
# actual:  1543
#
# sentence 475:
# predicted:  5
# actual:  5
#
# sentence 476:
# predicted:  2463
# actual:  2136
#
# sentence 477:
# predicted:  3
# actual:  958
#
# sentence 478:
# predicted:  9
# actual:  368
#
# sentence 479:
# predicted:  63
# actual:  9179
#
# sentence 480:
# predicted:  42
# actual:  613
#
# sentence 481:
# predicted:  29
# actual:  29
#
# sentence 482:
# predicted:  13
# actual:  13
#
# sentence 483:
# predicted:  22
# actual:  427
#
# sentence 484:
# predicted:  5
# actual:  5
#
# sentence 485:
# predicted:  1
# actual:  1
#
# sentence 486:
# predicted:  3540
# actual:  10034
#
# sentence 487:
# predicted:  1
# actual:  962
#
# sentence 488:
# predicted:  4746
# actual:  4746
#
# sentence 489:
# predicted:  9
# actual:  3169
#
# sentence 490:
# predicted:  17
# actual:  24
#
# sentence 491:
# predicted:  72
# actual:  1160
#
# sentence 492:
# predicted:  1
# actual:  3
#
# sentence 493:
# predicted:  1
# actual:  24
#
# sentence 494:
# predicted:  1
# actual:  1
#
# sentence 495:
# predicted:  4090
# actual:  37
#
# sentence 496:
# predicted:  19
# actual:  674
#
# sentence 497:
# predicted:  1
# actual:  1
#
# sentence 498:
# predicted:  8
# actual:  8
#
# sentence 499:
# predicted:  9
# actual:  50
#
# sentence 500:
# predicted:  3
# actual:  3
#
# sentence 501:
# predicted:  6
# actual:  897
#
# sentence 502:
# predicted:  3
# actual:  3
#
# sentence 503:
# predicted:  69
# actual:  52
#
# sentence 504:
# predicted:  443
# actual:  443
#
# sentence 505:
# predicted:  1
# actual:  1
#
# sentence 506:
# predicted:  2
# actual:  2
#
# sentence 507:
# predicted:  9
# actual:  9
#
# sentence 508:
# predicted:  1
# actual:  1
#
# sentence 509:
# predicted:  8
# actual:  8
#
# sentence 510:
# predicted:  9
# actual:  298
#
# sentence 511:
# predicted:  37
# actual:  152
#
# sentence 512:
# predicted:  5
# actual:  5
#
# sentence 513:
# predicted:  81
# actual:  81
#
# sentence 514:
# predicted:  565
# actual:  1300
#
# sentence 515:
# predicted:  416
# actual:  63
#
# sentence 516:
# predicted:  1
# actual:  1
#
# sentence 517:
# predicted:  22
# actual:  43
#
# sentence 518:
# predicted:  1
# actual:  1
#
# sentence 519:
# predicted:  2
# actual:  1
#
# sentence 520:
# predicted:  1
# actual:  553
#
# sentence 521:
# predicted:  22
# actual:  427
#
# sentence 522:
# predicted:  16
# actual:  1003
#
# sentence 523:
# predicted:  295
# actual:  705
#
# sentence 524:
# predicted:  9
# actual:  9
#
# sentence 525:
# predicted:  6
# actual:  5
#
# sentence 526:
# predicted:  1
# actual:  56
#
# sentence 527:
# predicted:  50
# actual:  2783
#
# sentence 528:
# predicted:  4
# actual:  95
#
# sentence 529:
# predicted:  215
# actual:  1785
#
# sentence 530:
# predicted:  166
# actual:  165
#
# sentence 531:
# predicted:  332
# actual:  155
#
# sentence 532:
# predicted:  2
# actual:  971
#
# sentence 533:
# predicted:  11
# actual:  3
#
# sentence 534:
# predicted:  4357
# actual:  3
#
# sentence 535:
# predicted:  27
# actual:  27
#
# sentence 536:
# predicted:  1
# actual:  1
#
# sentence 537:
# predicted:  5596
# actual:  4030
#
# sentence 538:
# predicted:  15
# actual:  15
#
# sentence 539:
# predicted:  3
# actual:  3
#
# sentence 540:
# predicted:  9
# actual:  318
#
# sentence 541:
# predicted:  87
# actual:  99
#
# sentence 542:
# predicted:  4
# actual:  7
#
# sentence 543:
# predicted:  6
# actual:  16
#
# sentence 544:
# predicted:  58
# actual:  58
#
# sentence 545:
# predicted:  1063
# actual:  5544
#
# sentence 546:
# predicted:  21
# actual:  21
#
# sentence 547:
# predicted:  249
# actual:  39
#
# sentence 548:
# predicted:  13
# actual:  13
#
# sentence 549:
# predicted:  1
# actual:  1
#
# sentence 550:
# predicted:  4
# actual:  5
#
# sentence 551:
# predicted:  90
# actual:  601
#
# sentence 552:
# predicted:  3
# actual:  4232
#
# sentence 553:
# predicted:  1
# actual:  27
#
# sentence 554:
# predicted:  89
# actual:  266
#
# sentence 555:
# predicted:  15
# actual:  1251
#
# sentence 556:
# predicted:  1809
# actual:  66
#
# sentence 557:
# predicted:  9
# actual:  825
#
# sentence 558:
# predicted:  3
# actual:  3
#
# sentence 559:
# predicted:  23
# actual:  23
#
# sentence 560:
# predicted:  138
# actual:  20
#
# sentence 561:
# predicted:  26
# actual:  85
#
# sentence 562:
# predicted:  182
# actual:  21
#
# sentence 563:
# predicted:  618
# actual:  509
#
# sentence 564:
# predicted:  6
# actual:  2
#
# sentence 565:
# predicted:  2
# actual:  1207
#
# sentence 566:
# predicted:  1
# actual:  591
#
# sentence 567:
# predicted:  4
# actual:  4
#
# sentence 568:
# predicted:  6
# actual:  6
#
# sentence 569:
# predicted:  3
# actual:  3
#
# sentence 570:
# predicted:  1
# actual:  1
#
# sentence 571:
# predicted:  24
# actual:  4
#
# sentence 572:
# predicted:  2
# actual:  146
#
# sentence 573:
# predicted:  9
# actual:  59
#
# sentence 574:
# predicted:  9
# actual:  70
#
# sentence 575:
# predicted:  250
# actual:  526
#
# sentence 576:
# predicted:  37
# actual:  1270
#
# sentence 577:
# predicted:  42
# actual:  1836
#
# sentence 578:
# predicted:  3
# actual:  12
#
# sentence 579:
# predicted:  1
# actual:  2
#
# sentence 580:
# predicted:  3
# actual:  22
#
# sentence 581:
# predicted:  42
# actual:  42
#
# sentence 582:
# predicted:  73
# actual:  88
#
# sentence 583:
# predicted:  7
# actual:  7
#
# sentence 584:
# predicted:  346
# actual:  2117
#
# sentence 585:
# predicted:  226
# actual:  67
#
# sentence 586:
# predicted:  12
# actual:  5377
#
# sentence 587:
# predicted:  7
# actual:  2
#
# sentence 588:
# predicted:  10
# actual:  606
#
# sentence 589:
# predicted:  9
# actual:  9
#
# sentence 590:
# predicted:  6
# actual:  36
#
# sentence 591:
# predicted:  109
# actual:  1785
#
# sentence 592:
# predicted:  5
# actual:  5
#
# sentence 593:
# predicted:  26
# actual:  26
#
# sentence 594:
# predicted:  1588
# actual:  105
#
# sentence 595:
# predicted:  5
# actual:  6
#
# sentence 596:
# predicted:  54
# actual:  3963
#
# sentence 597:
# predicted:  8
# actual:  8
#
# sentence 598:
# predicted:  12
# actual:  24
#
# sentence 599:
# predicted:  22
# actual:  103
#
# sentence 600:
# predicted:  27
# actual:  21
#
# sentence 601:
# predicted:  10
# actual:  16
#
# sentence 602:
# predicted:  39
# actual:  682
#
# sentence 603:
# predicted:  19
# actual:  1664
#
# sentence 604:
# predicted:  3
# actual:  40
#
# sentence 605:
# predicted:  5
# actual:  4
#
# sentence 606:
# predicted:  8
# actual:  8
#
# sentence 607:
# predicted:  210
# actual:  87
#
# sentence 608:
# predicted:  7
# actual:  68
#
# sentence 609:
# predicted:  37
# actual:  9936
#
# sentence 610:
# predicted:  8
# actual:  8
#
# sentence 611:
# predicted:  27
# actual:  1845
#
# sentence 612:
# predicted:  9
# actual:  755
#
# sentence 613:
# predicted:  1
# actual:  1
#
# sentence 614:
# predicted:  3
# actual:  4
#
# sentence 615:
# predicted:  1
# actual:  787
#
# sentence 616:
# predicted:  262
# actual:  22
#
# sentence 617:
# predicted:  9
# actual:  30
#
# sentence 618:
# predicted:  754
# actual:  754
#
# sentence 619:
# predicted:  2
# actual:  2
#
# sentence 620:
# predicted:  7
# actual:  27
#
# sentence 621:
# predicted:  407
# actual:  407
#
# sentence 622:
# predicted:  9
# actual:  3344
#
# sentence 623:
# predicted:  1
# actual:  1
# sentence 624:
# predicted:  17
# actual:  11
#
# sentence 625:
# predicted:  17
# actual:  161
#
# sentence 626:
# predicted:  34
# actual:  4571
#
# sentence 627:
# predicted:  51
# actual:  48
#
# sentence 628:
# predicted:  54
# actual:  3
#
# sentence 629:
# predicted:  2
# actual:  1106
#
# sentence 630:
# predicted:  48
# actual:  89
#
# sentence 631:
# predicted:  11
# actual:  12
#
# sentence 632:
# predicted:  1
# actual:  453
#
# sentence 633:
# predicted:  9
# actual:  2161
#
# sentence 634:
# predicted:  1
# actual:  1114
#
# sentence 635:
# predicted:  2
# actual:  15
#
# sentence 636:
# predicted:  2
# actual:  14
#
# sentence 637:
# predicted:  23
# actual:  15621
#
# sentence 638:
# predicted:  54
# actual:  111
#
# sentence 639:
# predicted:  1
# actual:  567
#
# sentence 640:
# predicted:  239
# actual:  1534
#
# sentence 641:
# predicted:  1
# actual:  9
#
# sentence 642:
# predicted:  144
# actual:  45
#
# sentence 643:
# predicted:  1
# actual:  2
#
# sentence 644:
# predicted:  10
# actual:  84
#
# sentence 645:
# predicted:  2
# actual:  2
#
# sentence 646:
# predicted:  72
# actual:  1705
#
# sentence 647:
# predicted:  12
# actual:  17
#
# sentence 648:
# predicted:  21
# actual:  8
#
# sentence 649:
# predicted:  9
# actual:  1658
#
# sentence 650:
# predicted:  1
# actual:  613
#
# sentence 651:
# predicted:  1
# actual:  2
#
# sentence 652:
# predicted:  6
# actual:  4
#
# sentence 653:
# predicted:  4
# actual:  27
#
# sentence 654:
# predicted:  165
# actual:  232
#
# sentence 655:
# predicted:  51
# actual:  70
#
# sentence 656:
# predicted:  9
# actual:  934
#
# sentence 657:
# predicted:  3
# actual:  3
#
# sentence 658:
# predicted:  9532
# actual:  9532
#
# sentence 659:
# predicted:  4
# actual:  4
#
# sentence 660:
# predicted:  29
# actual:  29
#
# sentence 661:
# predicted:  19
# actual:  721
#
# sentence 662:
# predicted:  7
# actual:  7
#
# sentence 663:
# predicted:  828
# actual:  2772
#
# sentence 664:
# predicted:  19
# actual:  498
#
# sentence 665:
# predicted:  9
# actual:  176
#
# sentence 666:
# predicted:  9
# actual:  73
#
# sentence 667:
# predicted:  4
# actual:  6
#
# sentence 668:
# predicted:  3
# actual:  3
#
# sentence 669:
# predicted:  4414
# actual:  4414
#
# sentence 670:
# predicted:  5
# actual:  5429
#
# sentence 671:
# predicted:  1
# actual:  1
#
# sentence 672:
# predicted:  3
# actual:  2210
#
# sentence 673:
# predicted:  10
# actual:  125
#
# sentence 674:
# predicted:  22
# actual:  887
#
# sentence 675:
# predicted:  4
# actual:  4
#
# sentence 676:
# predicted:  10
# actual:  139
#
# sentence 677:
# predicted:  50
# actual:  63
#
# sentence 678:
# predicted:  7
# actual:  6
#
# sentence 679:
# predicted:  9838
# actual:  34
#
# sentence 680:
# predicted:  1
# actual:  1
#
# sentence 681:
# predicted:  7335
# actual:  7335
#
# sentence 682:
# predicted:  2
# actual:  4783
#
# sentence 683:
# predicted:  2
# actual:  14
#
# sentence 684:
# predicted:  50
# actual:  50
#
# sentence 685:
# predicted:  782
# actual:  42
#
# sentence 686:
# predicted:  3
# actual:  42
#
# sentence 687:
# predicted:  1
# actual:  19
#
# sentence 688:
# predicted:  4
# actual:  27
#
# sentence 689:
# predicted:  22
# actual:  481
#
# sentence 690:
# predicted:  4035
# actual:  5
#
# sentence 691:
# predicted:  1
# actual:  2
#
# sentence 692:
# predicted:  165
# actual:  165
#
# sentence 693:
# predicted:  4
# actual:  4
#
# sentence 694:
# predicted:  6
# actual:  6
#
# sentence 695:
# predicted:  2
# actual:  267
#
# sentence 696:
# predicted:  357
# actual:  23
#
# sentence 697:
# predicted:  210
# actual:  1597
#
# sentence 698:
# predicted:  5
# actual:  3
#
# sentence 699:
# predicted:  22
# actual:  1228
#
# sentence 700:
# predicted:  101
# actual:  34
#
# sentence 701:
# predicted:  9
# actual:  187
#
# sentence 702:
# predicted:  8
# actual:  8
#
# sentence 703:
# predicted:  3
# actual:  482
#
# sentence 704:
# predicted:  9
# actual:  244
#
# sentence 705:
# predicted:  2
# actual:  2
#
# sentence 706:
# predicted:  4
# actual:  12
#
# sentence 707:
# predicted:  1
# actual:  1
#
# sentence 708:
# predicted:  6
# actual:  994
#
# sentence 709:
# predicted:  3
# actual:  3
#
# sentence 710:
# predicted:  57
# actual:  949
#
# sentence 711:
# predicted:  253
# actual:  253
#
# sentence 712:
# predicted:  2
# actual:  6
#
# sentence 713:
# predicted:  70
# actual:  23
#
# sentence 714:
# predicted:  1
# actual:  113
#
# sentence 715:
# predicted:  6
# actual:  5
#
# sentence 716:
# predicted:  4
# actual:  47
#
# sentence 717:
# predicted:  2
# actual:  1
#
# sentence 718:
# predicted:  200
# actual:  88
#
# sentence 719:
# predicted:  9
# actual:  311
#
# sentence 720:
# predicted:  3
# actual:  1132
#
# sentence 721:
# predicted:  30
# actual:  313
#
# sentence 722:
# predicted:  12984
# actual:  294
#
# sentence 723:
# predicted:  5
# actual:  890
#
# sentence 724:
# predicted:  8
# actual:  8
#
# sentence 725:
# predicted:  1
# actual:  29
#
# sentence 726:
# predicted:  9
# actual:  34
#
# sentence 727:
# predicted:  6
# actual:  47
#
# sentence 728:
# predicted:  3
# actual:  736
#
# sentence 729:
# predicted:  2
# actual:  506
#
# sentence 730:
# predicted:  20
# actual:  1
#
# sentence 731:
# predicted:  3
# actual:  3
#
# sentence 732:
# predicted:  1035
# actual:  2895
#
# sentence 733:
# predicted:  4
# actual:  4
#
# sentence 734:
# predicted:  22
# actual:  63
#
# sentence 735:
# predicted:  22
# actual:  8
#
# sentence 736:
# predicted:  182
# actual:  74
#
# sentence 737:
# predicted:  6
# actual:  16
#
# sentence 738:
# predicted:  4
# actual:  46
#
# sentence 739:
# predicted:  9
# actual:  470
#
# sentence 740:
# predicted:  374
# actual:  102
#
# sentence 741:
# predicted:  15
# actual:  10
#
# sentence 742:
# predicted:  1
# actual:  74
#
# sentence 743:
# predicted:  1
# actual:  33
#
# sentence 744:
# predicted:  7
# actual:  7
#
# sentence 745:
# predicted:  4
# actual:  39
#
# sentence 746:
# predicted:  26
# actual:  85
#
# sentence 747:
# predicted:  3
# actual:  68
#
# sentence 748:
# predicted:  13
# actual:  13
#
# sentence 749:
# predicted:  9
# actual:  8
#
# sentence 750:
# predicted:  2
# actual:  131
#
# sentence 751:
# predicted:  3
# actual:  69
#
# sentence 752:
# predicted:  39
# actual:  39
#
# sentence 753:
# predicted:  1
# actual:  1
#
# sentence 754:
# predicted:  1
# actual:  1
#
# sentence 755:
# predicted:  748
# actual:  469
#
# sentence 756:
# predicted:  179
# actual:  336
#
# sentence 757:
# predicted:  1
# actual:  1902
#
# sentence 758:
# predicted:  96
# actual:  96
#
# sentence 759:
# predicted:  4
# actual:  239
#
# sentence 760:
# predicted:  22
# actual:  22
#
# sentence 761:
# predicted:  1
# actual:  2
#
# sentence 762:
# predicted:  20
# actual:  5
#
# sentence 763:
# predicted:  1
# actual:  1
#
# sentence 764:
# predicted:  54
# actual:  1388
#
# sentence 765:
# predicted:  5
# actual:  5
#
# sentence 766:
# predicted:  3
# actual:  220
#
# sentence 767:
# predicted:  2
# actual:  36
#
# sentence 768:
# predicted:  4
# actual:  4
#
# sentence 769:
# predicted:  13
# actual:  13
#
# sentence 770:
# predicted:  1
# actual:  1
#
# sentence 771:
# predicted:  9
# actual:  113
#
# sentence 772:
# predicted:  1
# actual:  6443
#
# sentence 773:
# predicted:  55
# actual:  55
#
# sentence 774:
# predicted:  13
# actual:  149
#
# sentence 775:
# predicted:  8
# actual:  8
#
# sentence 776:
# predicted:  170
# actual:  742
#
# sentence 777:
# predicted:  5
# actual:  403
#
# sentence 778:
# predicted:  1
# actual:  1
#
# sentence 779:
# predicted:  1717
# actual:  1717
#
# sentence 780:
# predicted:  3546
# actual:  286
#
# sentence 781:
# predicted:  9
# actual:  862
#
# sentence 782:
# predicted:  7
# actual:  7
#
# sentence 783:
# predicted:  12
# actual:  104
#
# sentence 784:
# predicted:  370
# actual:  447
#
# sentence 785:
# predicted:  9
# actual:  9
#
# sentence 786:
# predicted:  19
# actual:  661
#
# sentence 787:
# predicted:  9
# actual:  123
#
# sentence 788:
# predicted:  1
# actual:  14
#
# sentence 789:
# predicted:  1
# actual:  14
#
# sentence 790:
# predicted:  238
# actual:  243
#
# sentence 791:
# predicted:  1
# actual:  6
#
# sentence 792:
# predicted:  4
# actual:  35
#
# sentence 793:
# predicted:  1
# actual:  2
#
# sentence 794:
# predicted:  16
# actual:  104
#
# sentence 795:
# predicted:  34
# actual:  34
#
# sentence 796:
# predicted:  54
# actual:  85
#
# sentence 797:
# predicted:  20
# actual:  22
#
# sentence 798:
# predicted:  3
# actual:  272
#
# sentence 799:
# predicted:  37
# actual:  49
#
# sentence 800:
# predicted:  3
# actual:  3
#
# sentence 801:
# predicted:  1
# actual:  448
#
# sentence 802:
# predicted:  9
# actual:  50
#
# sentence 803:
# predicted:  9
# actual:  395
#
# sentence 804:
# predicted:  4
# actual:  112
#
# sentence 805:
# predicted:  1
# actual:  1
#
# sentence 806:
# predicted:  2
# actual:  1
#
# sentence 807:
# predicted:  1
# actual:  1
#
# sentence 808:
# predicted:  9
# actual:  2186
#
# sentence 809:
# predicted:  17
# actual:  17
#
# sentence 810:
# predicted:  13
# actual:  646
#
# sentence 811:
# predicted:  8
# actual:  8
#
# sentence 812:
# predicted:  1
# actual:  1
#
# sentence 813:
# predicted:  9
# actual:  544
#
# sentence 814:
# predicted:  1469
# actual:  964
#
# sentence 815:
# predicted:  1
# actual:  35
#
# sentence 816:
# predicted:  20
# actual:  1303
#
# sentence 817:
# predicted:  5
# actual:  5
#
# sentence 818:
# predicted:  4
# actual:  4
#
# sentence 819:
# predicted:  24
# actual:  5
#
# sentence 820:
# predicted:  6
# actual:  6
#
# sentence 821:
# predicted:  7
# actual:  5
#
# sentence 822:
# predicted:  30
# actual:  51
#
# sentence 823:
# predicted:  9
# actual:  131
#
# sentence 824:
# predicted:  3
# actual:  3
#
# sentence 825:
# predicted:  5
# actual:  15
#
# sentence 826:
# predicted:  10
# actual:  29
# sentence 827:
# predicted:  9
# actual:  1915
#
# sentence 828:
# predicted:  1
# actual:  235
#
# sentence 829:
# predicted:  26
# actual:  26
#
# sentence 830:
# predicted:  11
# actual:  3
#
# sentence 831:
# predicted:  1
# actual:  2
#
# sentence 832:
# predicted:  17
# actual:  12
#
# sentence 833:
# predicted:  9
# actual:  117
#
# sentence 834:
# predicted:  4
# actual:  5
#
# sentence 835:
# predicted:  9
# actual:  131
#
# sentence 836:
# predicted:  4
# actual:  6
#
# sentence 837:
# predicted:  495
# actual:  39
#
# sentence 838:
# predicted:  495
# actual:  3
#
# sentence 839:
# predicted:  144
# actual:  679
#
# sentence 840:
# predicted:  4
# actual:  1367
#
# sentence 841:
# predicted:  4
# actual:  367
#
# sentence 842:
# predicted:  1
# actual:  32
#
# sentence 843:
# predicted:  6
# actual:  73
#
# sentence 844:
# predicted:  2
# actual:  146
#
# sentence 845:
# predicted:  47
# actual:  4
#
# sentence 846:
# predicted:  21
# actual:  5
#
# sentence 847:
# predicted:  22
# actual:  5054
#
# sentence 848:
# predicted:  1
# actual:  1027
#
# sentence 849:
# predicted:  72
# actual:  443
#
# sentence 850:
# predicted:  37
# actual:  990
#
# sentence 851:
# predicted:  10
# actual:  10
#
# sentence 852:
# predicted:  5
# actual:  5
#
# sentence 853:
# predicted:  1
# actual:  1
#
# sentence 854:
# predicted:  13
# actual:  4593
#
# sentence 855:
# predicted:  774
# actual:  130
#
# sentence 856:
# predicted:  6
# actual:  17
#
# sentence 857:
# predicted:  51
# actual:  640
#
# sentence 858:
# predicted:  3
# actual:  3
#
# sentence 859:
# predicted:  1
# actual:  1967
#
# sentence 860:
# predicted:  83
# actual:  8
#
# sentence 861:
# predicted:  3
# actual:  244
#
# sentence 862:
# predicted:  3
# actual:  44
#
# sentence 863:
# predicted:  13
# actual:  13
#
# sentence 864:
# predicted:  4
# actual:  6
#
# sentence 865:
# predicted:  42
# actual:  56
#
# sentence 866:
# predicted:  5633
# actual:  235
#
# sentence 867:
# predicted:  5
# actual:  2
#
# sentence 868:
# predicted:  4
# actual:  4
#
# sentence 869:
# predicted:  219
# actual:  5011
#
# sentence 870:
# predicted:  4
# actual:  669
#
# sentence 871:
# predicted:  1525
# actual:  1525
#
# sentence 872:
# predicted:  3
# actual:  3
#
# sentence 873:
# predicted:  4
# actual:  60
#
# sentence 874:
# predicted:  1
# actual:  1
#
# sentence 875:
# predicted:  6
# actual:  25
#
# sentence 876:
# predicted:  4
# actual:  12
#
# sentence 877:
# predicted:  1
# actual:  29
#
# sentence 878:
# predicted:  4
# actual:  6
#
# sentence 879:
# predicted:  1
# actual:  2085
#
# sentence 880:
# predicted:  8
# actual:  8
#
# sentence 881:
# predicted:  5
# actual:  24
#
# sentence 882:
# predicted:  1
# actual:  2
#
# sentence 883:
# predicted:  17
# actual:  17
#
# sentence 884:
# predicted:  9
# actual:  7345
#
# sentence 885:
# predicted:  5
# actual:  5
#
# sentence 886:
# predicted:  6
# actual:  5
#
# sentence 887:
# predicted:  13
# actual:  13
#
# sentence 888:
# predicted:  81
# actual:  501
#
# sentence 889:
# predicted:  1
# actual:  1
#
# sentence 890:
# predicted:  1201
# actual:  1201
#
# sentence 891:
# predicted:  3
# actual:  2588
#
# sentence 892:
# predicted:  59
# actual:  354
#
# sentence 893:
# predicted:  17
# actual:  12
#
# sentence 894:
# predicted:  114
# actual:  252
#
# sentence 895:
# predicted:  7
# actual:  7
#
# sentence 896:
# predicted:  3
# actual:  8
#
# sentence 897:
# predicted:  1
# actual:  3
#
# sentence 898:
# predicted:  7
# actual:  7
#
# sentence 899:
# predicted:  4
# actual:  77
#
# sentence 900:
# predicted:  81
# actual:  81
#
# sentence 901:
# predicted:  10
# actual:  16
#
# sentence 902:
# predicted:  39
# actual:  6
#
# sentence 903:
# predicted:  13
# actual:  904
#
# sentence 904:
# predicted:  6
# actual:  11
#
# sentence 905:
# predicted:  165
# actual:  91
#
# sentence 906:
# predicted:  72
# actual:  177
#
# sentence 907:
# predicted:  16156
# actual:  6
#
# sentence 908:
# predicted:  1
# actual:  1337
#
# sentence 909:
# predicted:  9
# actual:  492
#
# sentence 910:
# predicted:  13
# actual:  115
#
# sentence 911:
# predicted:  111
# actual:  134
#
# sentence 912:
# predicted:  72
# actual:  72
#
# sentence 913:
# predicted:  4
# actual:  11
#
# sentence 914:
# predicted:  89
# actual:  23
#
# sentence 915:
# predicted:  21
# actual:  21
#
# sentence 916:
# predicted:  13
# actual:  13
#
# sentence 917:
# predicted:  302
# actual:  44
#
# sentence 918:
# predicted:  13
# actual:  13
#
# sentence 919:
# predicted:  3
# actual:  3
#
# sentence 920:
# predicted:  22
# actual:  53
#
# sentence 921:
# predicted:  257
# actual:  257
#
# sentence 922:
# predicted:  13
# actual:  13
#
# sentence 923:
# predicted:  60
# actual:  246
#
# sentence 924:
# predicted:  21
# actual:  322
#
# sentence 925:
# predicted:  212
# actual:  525
#
# sentence 926:
# predicted:  10
# actual:  114
#
# sentence 927:
# predicted:  614
# actual:  588
#
# sentence 928:
# predicted:  203
# actual:  1396
#
# sentence 929:
# predicted:  1
# actual:  2
#
# sentence 930:
# predicted:  182
# actual:  4754
#
# sentence 931:
# predicted:  1
# actual:  1
#
# sentence 932:
# predicted:  12
# actual:  12
#
# sentence 933:
# predicted:  22
# actual:  568
#
# sentence 934:
# predicted:  24
# actual:  12
#
# sentence 935:
# predicted:  1
# actual:  2
#
# sentence 936:
# predicted:  9
# actual:  129
#
# sentence 937:
# predicted:  2
# actual:  1
#
# sentence 938:
# predicted:  15
# actual:  27
#
# sentence 939:
# predicted:  2862
# actual:  2862
#
# sentence 940:
# predicted:  1
# actual:  262
#
# sentence 941:
# predicted:  111
# actual:  578
#
# sentence 942:
# predicted:  5
# actual:  5
#
# sentence 943:
# predicted:  19
# actual:  132
#
# sentence 944:
# predicted:  24
# actual:  79
#
# sentence 945:
# predicted:  2
# actual:  7
#
# sentence 946:
# predicted:  2
# actual:  367
#
# sentence 947:
# predicted:  3
# actual:  6
#
# sentence 948:
# predicted:  1982
# actual:  749
#
# sentence 949:
# predicted:  1
# actual:  2
#
# sentence 950:
# predicted:  9
# actual:  8503
#
# sentence 951:
# predicted:  6
# actual:  4
#
# sentence 952:
# predicted:  7
# actual:  7
#
# sentence 953:
# predicted:  19
# actual:  8
#
# sentence 954:
# predicted:  3
# actual:  69
#
# sentence 955:
# predicted:  13
# actual:  18
#
# sentence 956:
# predicted:  345
# actual:  367
#
# sentence 957:
# predicted:  3
# actual:  4
#
# sentence 958:
# predicted:  9
# actual:  282
#
# sentence 959:
# predicted:  719
# actual:  872
#
# sentence 960:
# predicted:  54
# actual:  634
#
# sentence 961:
# predicted:  38
# actual:  49
#
# sentence 962:
# predicted:  4
# actual:  6
#
# sentence 963:
# predicted:  1338
# actual:  2397
#
# sentence 964:
# predicted:  1
# actual:  2
#
# sentence 965:
# predicted:  9
# actual:  298
#
# sentence 966:
# predicted:  15
# actual:  12
#
# sentence 967:
# predicted:  91
# actual:  3
#
# sentence 968:
# predicted:  4
# actual:  24
#
# sentence 969:
# predicted:  217
# actual:  217
#
# sentence 970:
# predicted:  3
# actual:  3
#
# sentence 971:
# predicted:  1
# actual:  1
#
# sentence 972:
# predicted:  3
# actual:  3
#
# sentence 973:
# predicted:  7
# actual:  186
#
# sentence 974:
# predicted:  9
# actual:  1725
#
# sentence 975:
# predicted:  49
# actual:  576
#
# sentence 976:
# predicted:  1
# actual:  1
#
# sentence 977:
# predicted:  97
# actual:  97
#
# sentence 978:
# predicted:  345
# actual:  5260
#
# sentence 979:
# predicted:  1092
# actual:  1697
#
# sentence 980:
# predicted:  6
# actual:  2792
#
# sentence 981:
# predicted:  1
# actual:  1
#
# sentence 982:
# predicted:  16087
# actual:  2304
#
# sentence 983:
# predicted:  2
# actual:  2
#
# sentence 984:
# predicted:  204
# actual:  4
#
# sentence 985:
# predicted:  3
# actual:  3
#
# sentence 986:
# predicted:  6
# actual:  12
#
# sentence 987:
# predicted:  6
# actual:  27
#
# sentence 988:
# predicted:  86
# actual:  86
#
# sentence 989:
# predicted:  4
# actual:  3
#
# sentence 990:
# predicted:  85
# actual:  4700
#
# sentence 991:
# predicted:  20
# actual:  233
#
# sentence 992:
# predicted:  9
# actual:  1168
#
# sentence 993:
# predicted:  1
# actual:  1
#
# sentence 994:
# predicted:  6
# actual:  23
#
# sentence 995:
# predicted:  1
# actual:  1
#
# sentence 996:
# predicted:  3
# actual:  6
#
# sentence 997:
# predicted:  7
# actual:  7
#
# sentence 998:
# predicted:  8
# actual:  83
#
# sentence 999:
# predicted:  1
# actual:  369
# numpy.int64

# %%
loaded_seq = np.load("./C_test_set/org_seq.npy")
loaded_rnn_gen = np.load("./C_test_set/rnn_result.npy")
loaded_actual = np.load("./C_test_set/actual_result.npy")

loaded_seq.shape
loaded_rnn_gen.shape
loaded_actual.shape

type(loaded_seq[0][0])
type(loaded_rnn_gen[0])
type(loaded_actual[0])
# Out:
# (1000, 50)
# (1000,)
# (1000,)
# numpy.int64
# numpy.int64
# numpy.int64
